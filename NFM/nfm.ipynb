# %%
import os
import sys
import pytest
import inspect
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf

from copy import copy
from itertools import chain
from numpy.testing import assert_allclose
from tensorflow.python.layers import utils
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.backend import batch_dot
from tensorflow.python.estimator.canned.head import _Head
from collections import namedtuple, OrderedDict, defaultdict
from tensorflow.python.keras.models import Model, load_model, save_model
from tensorflow.python.estimator.canned.optimizers import get_optimizer_instance
from tensorflow.python.keras.layers import Input, Masking, Flatten, Layer, Embedding
from tensorflow.python.keras.initializers import RandomNormal,Zeros, glorot_normal,glorot_uniform, TruncatedNormal

# %%
class PredictionLayer(Layer):

    def __init__(self, task='binary', use_bias=True, **kwargs):
        if task not in ["binary", "multiclass", "regression"]:
            raise ValueError("task must be binary,multiclass or regression")
        self.task = task
        self.use_bias = use_bias
        super(PredictionLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        if self.use_bias:
            self.global_bias = self.add_weight(
                shape=(1,), initializer=Zeros(), name="global_bias")

        # Be sure to call this somewhere!
        super(PredictionLayer, self).build(input_shape)

    def call(self, inputs, **kwargs):
        x = inputs
        if self.use_bias:
            x = tf.nn.bias_add(x, self.global_bias, data_format='NHWC')
        if self.task == "binary":
            x = tf.sigmoid(x)

        output = tf.reshape(x, (-1, 1))

        return output

    def compute_output_shape(self, input_shape):
        return (None, 1)

    def get_config(self, ):
        config = {'task': self.task, 'use_bias': self.use_bias}
        base_config = super(PredictionLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def activation_layer(activation):
    if activation in ("dice", "Dice"):
        act_layer = Dice()
    elif isinstance(activation, (str, unicode)):
        act_layer = tf.keras.layers.Activation(activation)
    elif issubclass(activation, Layer):
        act_layer = activation()
    else:
        raise ValueError(
            "Invalid activation,found %s.You should use a str or a Activation Layer Class." % (activation))
    return act_layer

# %%
class DNN(Layer):
    """The Multi Layer Percetron
      Input shape
        - nD tensor with shape: ``(batch_size, ..., input_dim)``. The most common situation would be a 2D input with shape ``(batch_size, input_dim)``.
      Output shape
        - nD tensor with shape: ``(batch_size, ..., hidden_size[-1])``. For instance, for a 2D input with shape ``(batch_size, input_dim)``, the output would have shape ``(batch_size, hidden_size[-1])``.
      Arguments
        - **hidden_units**:list of positive integer, the layer number and units in each layer.
        - **activation**: Activation function to use.
        - **l2_reg**: float between 0 and 1. L2 regularizer strength applied to the kernel weights matrix.
        - **dropout_rate**: float in [0,1). Fraction of the units to dropout.
        - **use_bn**: bool. Whether use BatchNormalization before activation or not.
        - **output_activation**: Activation function to use in the last layer.If ``None``,it will be same as ``activation``.
        - **seed**: A Python integer to use as random seed.
    """

    def __init__(self, hidden_units, activation='relu', l2_reg=0, dropout_rate=0, use_bn=False, output_activation=None,
                 seed=1024, **kwargs):
        self.hidden_units = hidden_units
        self.activation = activation
        self.l2_reg = l2_reg
        self.dropout_rate = dropout_rate
        self.use_bn = use_bn
        self.output_activation = output_activation
        self.seed = seed

        super(DNN, self).__init__(**kwargs)

    def build(self, input_shape):
        # if len(self.hidden_units) == 0:
        #     raise ValueError("hidden_units is empty")
        input_size = input_shape[-1]
        hidden_units = [int(input_size)] + list(self.hidden_units)
        self.kernels = [self.add_weight(name='kernel' + str(i),
                                        shape=(
                                            hidden_units[i], hidden_units[i + 1]),
                                        initializer=glorot_normal(
                                            seed=self.seed),
                                        regularizer=l2(self.l2_reg),
                                        trainable=True) for i in range(len(self.hidden_units))]
        self.bias = [self.add_weight(name='bias' + str(i),
                                     shape=(self.hidden_units[i],),
                                     initializer=Zeros(),
                                     trainable=True) for i in range(len(self.hidden_units))]
        if self.use_bn:
            self.bn_layers = [tf.keras.layers.BatchNormalization() for _ in range(len(self.hidden_units))]

        self.dropout_layers = [tf.keras.layers.Dropout(self.dropout_rate, seed=self.seed + i) for i in
                               range(len(self.hidden_units))]

        self.activation_layers = [activation_layer(self.activation) for _ in range(len(self.hidden_units))]

        if self.output_activation:
            self.activation_layers[-1] = activation_layer(self.output_activation)

        super(DNN, self).build(input_shape)  # Be sure to call this somewhere!

    def call(self, inputs, training=None, **kwargs):

        deep_input = inputs

        for i in range(len(self.hidden_units)):
            fc = tf.nn.bias_add(tf.tensordot(
                deep_input, self.kernels[i], axes=(-1, 0)), self.bias[i])

            if self.use_bn:
                fc = self.bn_layers[i](fc, training=training)

            fc = self.activation_layers[i](fc)

            fc = self.dropout_layers[i](fc, training=training)
            deep_input = fc

        return deep_input

    def compute_output_shape(self, input_shape):
        if len(self.hidden_units) > 0:
            shape = input_shape[:-1] + (self.hidden_units[-1],)
        else:
            shape = input_shape

        return tuple(shape)

    def get_config(self, ):
        config = {'activation': self.activation, 'hidden_units': self.hidden_units,
                  'l2_reg': self.l2_reg, 'use_bn': self.use_bn, 'dropout_rate': self.dropout_rate,
                  'output_activation': self.output_activation, 'seed': self.seed}
        base_config = super(DNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def combined_dnn_input(sparse_embedding_list, dense_value_list):
    if len(sparse_embedding_list) > 0 and len(dense_value_list) > 0:
        sparse_dnn_input = Flatten()(concat_func(sparse_embedding_list))
        dense_dnn_input = Flatten()(concat_func(dense_value_list))
        return concat_func([sparse_dnn_input, dense_dnn_input])
    elif len(sparse_embedding_list) > 0:
        return Flatten()(concat_func(sparse_embedding_list))
    elif len(dense_value_list) > 0:
        return Flatten()(concat_func(dense_value_list))
    else:
        raise NotImplementedError("dnn_feature_columns can not be empty list")

# %%
class BiInteractionPooling(Layer):
    """Bi-Interaction Layer used in Neural FM,compress the
     pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
        - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
      References
        - [He X, Chua T S. Neural factorization machines for sparse predictive analytics[C]//Proceedings of the 40th International ACM SIGIR conference on Research and Development in Information Retrieval. ACM, 2017: 355-364.](http://arxiv.org/abs/1708.05027)
    """

    def __init__(self, **kwargs):

        super(BiInteractionPooling, self).__init__(**kwargs)

    def build(self, input_shape):

        if len(input_shape) != 3:
            raise ValueError(
                "Unexpected inputs dimensions %d, expect to be 3 dimensions" % (len(input_shape)))

        super(BiInteractionPooling, self).build(
            input_shape)  # Be sure to call this somewhere!

    def call(self, inputs, **kwargs):

        if K.ndim(inputs) != 3:
            raise ValueError(
                "Unexpected inputs dimensions %d, expect to be 3 dimensions" % (K.ndim(inputs)))

        concated_embeds_value = inputs
        square_of_sum = tf.square(reduce_sum(
            concated_embeds_value, axis=1, keep_dims=True))
        sum_of_square = reduce_sum(
            concated_embeds_value * concated_embeds_value, axis=1, keep_dims=True)
        cross_term = 0.5 * (square_of_sum - sum_of_square)

        return cross_term

    def compute_output_shape(self, input_shape):
        return (None, 1, input_shape[-1])

# %%
def concat_func(inputs, axis=-1, mask=False):
    if not mask:
        inputs = list(map(NoMask(), inputs))
    if len(inputs) == 1:
        return inputs[0]
    else:
        return tf.keras.layers.Concatenate(axis=axis)(inputs)

def add_func(inputs):
    return Add()(inputs)

def reduce_sum(input_tensor,
               axis=None,
               keep_dims=False,
               name=None,
               reduction_indices=None):
    try:
        return tf.reduce_sum(input_tensor,
                             axis=axis,
                             keep_dims=keep_dims,
                             name=name,
                             reduction_indices=reduction_indices)
    except TypeError:
        return tf.reduce_sum(input_tensor,
                             axis=axis,
                             keepdims=keep_dims,
                             name=name)

# %%
def create_embedding_matrix(feature_columns, l2_reg, seed, prefix="", seq_mask_zero=True):
    #from . import feature_column as fc_lib

    sparse_feature_columns = list(
        filter(lambda x: isinstance(x, SparseFeat), feature_columns)) if feature_columns else []
    varlen_sparse_feature_columns = list(
        filter(lambda x: isinstance(x, VarLenSparseFeat), feature_columns)) if feature_columns else []
    sparse_emb_dict = create_embedding_dict(sparse_feature_columns, varlen_sparse_feature_columns, seed,
                                            l2_reg, prefix=prefix + 'sparse', seq_mask_zero=seq_mask_zero)
    return sparse_emb_dict

# %%
def create_embedding_dict(sparse_feature_columns, varlen_sparse_feature_columns, seed, l2_reg,
                          prefix='sparse_', seq_mask_zero=True):
    sparse_embedding = {}
    for feat in sparse_feature_columns:
        emb = Embedding(feat.vocabulary_size, feat.embedding_dim,
                        embeddings_initializer=feat.embeddings_initializer,
                        embeddings_regularizer=l2(l2_reg),
                        name=prefix + '_emb_' + feat.embedding_name)
        emb.trainable = feat.trainable
        sparse_embedding[feat.embedding_name] = emb

    if varlen_sparse_feature_columns and len(varlen_sparse_feature_columns) > 0:
        for feat in varlen_sparse_feature_columns:
            # if feat.name not in sparse_embedding:
            emb = Embedding(feat.vocabulary_size, feat.embedding_dim,
                            embeddings_initializer=feat.embeddings_initializer,
                            embeddings_regularizer=l2(
                                l2_reg),
                            name=prefix + '_seq_emb_' + feat.name,
                            mask_zero=seq_mask_zero)
            emb.trainable = feat.trainable
            sparse_embedding[feat.embedding_name] = emb
    return sparse_embedding

# %%
def input_from_feature_columns(features, feature_columns, l2_reg, seed, prefix='', seq_mask_zero=True,
                               support_dense=True, support_group=False):
    sparse_feature_columns = list(
        filter(lambda x: isinstance(x, SparseFeat), feature_columns)) if feature_columns else []
    varlen_sparse_feature_columns = list(
        filter(lambda x: isinstance(x, VarLenSparseFeat), feature_columns)) if feature_columns else []

    embedding_matrix_dict = create_embedding_matrix(feature_columns, l2_reg, seed, prefix=prefix,
                                                    seq_mask_zero=seq_mask_zero)
    group_sparse_embedding_dict = embedding_lookup(embedding_matrix_dict, features, sparse_feature_columns)
    dense_value_list = get_dense_input(features, feature_columns)
    if not support_dense and len(dense_value_list) > 0:
        raise ValueError("DenseFeat is not supported in dnn_feature_columns")

    sequence_embed_dict = varlen_embedding_lookup(embedding_matrix_dict, features, varlen_sparse_feature_columns)
    group_varlen_sparse_embedding_dict = get_varlen_pooling_list(sequence_embed_dict, features,
                                                                 varlen_sparse_feature_columns)
    group_embedding_dict = mergeDict(group_sparse_embedding_dict, group_varlen_sparse_embedding_dict)
    if not support_group:
        group_embedding_dict = list(chain.from_iterable(group_embedding_dict.values()))
    return group_embedding_dict, dense_value_list

# %%
def embedding_lookup(sparse_embedding_dict, sparse_input_dict, sparse_feature_columns, return_feat_list=(),
                     mask_feat_list=(), to_list=False):
    group_embedding_dict = defaultdict(list)
    for fc in sparse_feature_columns:
        feature_name = fc.name
        embedding_name = fc.embedding_name
        if (len(return_feat_list) == 0 or feature_name in return_feat_list):
            if fc.use_hash:
                lookup_idx = Hash(fc.vocabulary_size, mask_zero=(feature_name in mask_feat_list))(
                    sparse_input_dict[feature_name])
            else:
                lookup_idx = sparse_input_dict[feature_name]

            group_embedding_dict[fc.group_name].append(sparse_embedding_dict[embedding_name](lookup_idx))
    if to_list:
        return list(chain.from_iterable(group_embedding_dict.values()))
    return group_embedding_dict

# %%
class VarLenSparseFeat(namedtuple('VarLenSparseFeat',
                                  ['sparsefeat', 'maxlen', 'combiner', 'length_name', 'weight_name', 'weight_norm'])):
    __slots__ = ()

    def __new__(cls, sparsefeat, maxlen, combiner="mean", length_name=None, weight_name=None, weight_norm=True):
        return super(VarLenSparseFeat, cls).__new__(cls, sparsefeat, maxlen, combiner, length_name, weight_name,
                                                    weight_norm)

    @property
    def name(self):
        return self.sparsefeat.name

    @property
    def vocabulary_size(self):
        return self.sparsefeat.vocabulary_size

    @property
    def embedding_dim(self):
        return self.sparsefeat.embedding_dim

    @property
    def use_hash(self):
        return self.sparsefeat.use_hash

    @property
    def dtype(self):
        return self.sparsefeat.dtype

    @property
    def embeddings_initializer(self):
        return self.sparsefeat.embeddings_initializer

    @property
    def embedding_name(self):
        return self.sparsefeat.embedding_name

    @property
    def group_name(self):
        return self.sparsefeat.group_name

    @property
    def trainable(self):
        return self.sparsefeat.trainable

    def __hash__(self):
        return self.name.__hash__()

# %%
class DenseFeat(namedtuple('DenseFeat', ['name', 'dimension', 'dtype'])):
    __slots__ = ()

    def __new__(cls, name, dimension=1, dtype="float32"):
        return super(DenseFeat, cls).__new__(cls, name, dimension, dtype)

    def __hash__(self):
        return self.name.__hash__()

# %%
DEFAULT_GROUP_NAME = "default_group"
class SparseFeat(namedtuple('SparseFeat',
                            ['name', 'vocabulary_size', 'embedding_dim', 'use_hash', 'dtype', 'embeddings_initializer',
                             'embedding_name',
                             'group_name', 'trainable'])):
    __slots__ = ()

    def __new__(cls, name, vocabulary_size, embedding_dim=4, use_hash=False, dtype="int32", embeddings_initializer=None,
                embedding_name=None,
                group_name=DEFAULT_GROUP_NAME, trainable=True):

        if embedding_dim == "auto":
            embedding_dim = 6 * int(pow(vocabulary_size, 0.25))
        if embeddings_initializer is None:
            embeddings_initializer = RandomNormal(mean=0.0, stddev=0.0001, seed=2020)

        if embedding_name is None:
            embedding_name = name

        return super(SparseFeat, cls).__new__(cls, name, vocabulary_size, embedding_dim, use_hash, dtype,
                                              embeddings_initializer,
                                              embedding_name, group_name, trainable)

    def __hash__(self):
        return self.name.__hash__()

# %%
def get_linear_logit(features, feature_columns, units=1, use_bias=False, seed=1024, prefix='linear',
                     l2_reg=0):
    linear_feature_columns = copy(feature_columns)
    for i in range(len(linear_feature_columns)):
        if isinstance(linear_feature_columns[i], SparseFeat):
            linear_feature_columns[i] = linear_feature_columns[i]._replace(embedding_dim=1,
                                                                           embeddings_initializer=Zeros())
        if isinstance(linear_feature_columns[i], VarLenSparseFeat):
            linear_feature_columns[i] = linear_feature_columns[i]._replace(
                sparsefeat=linear_feature_columns[i].sparsefeat._replace(embedding_dim=1,
                                                                         embeddings_initializer=Zeros()))

    linear_emb_list = [input_from_feature_columns(features, linear_feature_columns, l2_reg, seed,
                                                  prefix=prefix + str(i))[0] for i in range(units)]
    _, dense_input_list = input_from_feature_columns(features, linear_feature_columns, l2_reg, seed, prefix=prefix)

    linear_logit_list = []
    for i in range(units):

        if len(linear_emb_list[i]) > 0 and len(dense_input_list) > 0:
            sparse_input = concat_func(linear_emb_list[i])
            dense_input = concat_func(dense_input_list)
            linear_logit = Linear(l2_reg, mode=2, use_bias=use_bias, seed=seed)([sparse_input, dense_input])
        elif len(linear_emb_list[i]) > 0:
            sparse_input = concat_func(linear_emb_list[i])
            linear_logit = Linear(l2_reg, mode=0, use_bias=use_bias, seed=seed)(sparse_input)
        elif len(dense_input_list) > 0:
            dense_input = concat_func(dense_input_list)
            linear_logit = Linear(l2_reg, mode=1, use_bias=use_bias, seed=seed)(dense_input)
        else:
            # raise NotImplementedError
            return add_func([])
        linear_logit_list.append(linear_logit)

    return concat_func(linear_logit_list)

# %%
def build_input_features(feature_columns, prefix=''):
    input_features = OrderedDict()
    for fc in feature_columns:
        if isinstance(fc, SparseFeat):
            input_features[fc.name] = Input(
                shape=(1,), name=prefix + fc.name, dtype=fc.dtype)
        elif isinstance(fc, DenseFeat):
            input_features[fc.name] = Input(
                shape=(fc.dimension,), name=prefix + fc.name, dtype=fc.dtype)
        elif isinstance(fc, VarLenSparseFeat):
            input_features[fc.name] = Input(shape=(fc.maxlen,), name=prefix + fc.name,
                                            dtype=fc.dtype)
            if fc.weight_name is not None:
                input_features[fc.weight_name] = Input(shape=(fc.maxlen, 1), name=prefix + fc.weight_name,
                                                       dtype="float32")
            if fc.length_name is not None:
                input_features[fc.length_name] = Input((1,), name=prefix + fc.length_name, dtype='int32')

        else:
            raise TypeError("Invalid feature column type,got", type(fc))

    return input_features

# %%
def NFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(128, 128),
        l2_reg_embedding=1e-5, l2_reg_linear=1e-5, l2_reg_dnn=0, seed=1024, bi_dropout=0,
        dnn_dropout=0, dnn_activation='relu', task='binary'):
    """Instantiates the Neural Factorization Machine architecture.
    :param linear_feature_columns: An iterable containing all the features used by linear part of the model.
    :param dnn_feature_columns: An iterable containing all the features used by deep part of the model.
    :param dnn_hidden_units: list,list of positive integer or empty list, the layer number and units in each layer of deep net
    :param l2_reg_embedding: float. L2 regularizer strength applied to embedding vector
    :param l2_reg_linear: float. L2 regularizer strength applied to linear part.
    :param l2_reg_dnn: float . L2 regularizer strength applied to DNN
    :param seed: integer ,to use as random seed.
    :param biout_dropout: When not ``None``, the probability we will drop out the output of BiInteractionPooling Layer.
    :param dnn_dropout: float in [0,1), the probability we will drop out a given DNN coordinate.
    :param dnn_activation: Activation function to use in deep net
    :param task: str, ``"binary"`` for  binary logloss or  ``"regression"`` for regression loss
    :return: A Keras model instance.
    """

    features = build_input_features(
        linear_feature_columns + dnn_feature_columns)

    inputs_list = list(features.values())

    linear_logit = get_linear_logit(features, linear_feature_columns, seed=seed, prefix='linear',
                                    l2_reg=l2_reg_linear)

    sparse_embedding_list, dense_value_list = input_from_feature_columns(features, dnn_feature_columns,
                                                                         l2_reg_embedding, seed)

    fm_input = concat_func(sparse_embedding_list, axis=1)
    bi_out = BiInteractionPooling()(fm_input)
    if bi_dropout:
        bi_out = tf.keras.layers.Dropout(bi_dropout)(bi_out, training=None)
    dnn_input = combined_dnn_input([bi_out], dense_value_list)
    dnn_output = DNN(dnn_hidden_units, dnn_activation, l2_reg_dnn, dnn_dropout, False, seed=seed)(dnn_input)
    dnn_logit = tf.keras.layers.Dense(
        1, use_bias=False, kernel_initializer=tf.keras.initializers.glorot_normal(seed))(dnn_output)

    final_logit = add_func([linear_logit, dnn_logit])

    output = PredictionLayer(task)(final_logit)

    model = tf.keras.models.Model(inputs=inputs_list, outputs=output)
    return model

# %%
def get_feature_names(feature_columns):
    features = build_input_features(feature_columns)
    return list(features.keys())

# %%
def get_dense_input(features, feature_columns):
    dense_feature_columns = list(
        filter(lambda x: isinstance(x, DenseFeat), feature_columns)) if feature_columns else []
    dense_input_list = []
    for fc in dense_feature_columns:
        dense_input_list.append(features[fc.name])
    return dense_input_list

# %%
def varlen_embedding_lookup(embedding_dict, sequence_input_dict, varlen_sparse_feature_columns):
    varlen_embedding_vec_dict = {}
    for fc in varlen_sparse_feature_columns:
        feature_name = fc.name
        embedding_name = fc.embedding_name
        if fc.use_hash:
            lookup_idx = Hash(fc.vocabulary_size, mask_zero=True)(sequence_input_dict[feature_name])
        else:
            lookup_idx = sequence_input_dict[feature_name]
        varlen_embedding_vec_dict[feature_name] = embedding_dict[embedding_name](lookup_idx)
    return varlen_embedding_vec_dict

# %%
def get_varlen_pooling_list(embedding_dict, features, varlen_sparse_feature_columns, to_list=False):
    pooling_vec_list = defaultdict(list)
    for fc in varlen_sparse_feature_columns:
        feature_name = fc.name
        combiner = fc.combiner
        feature_length_name = fc.length_name
        if feature_length_name is not None:
            if fc.weight_name is not None:
                seq_input = WeightedSequenceLayer(weight_normalization=fc.weight_norm)(
                    [embedding_dict[feature_name], features[feature_length_name], features[fc.weight_name]])
            else:
                seq_input = embedding_dict[feature_name]
            vec = SequencePoolingLayer(combiner, supports_masking=False)(
                [seq_input, features[feature_length_name]])
        else:
            if fc.weight_name is not None:
                seq_input = WeightedSequenceLayer(weight_normalization=fc.weight_norm, supports_masking=True)(
                    [embedding_dict[feature_name], features[fc.weight_name]])
            else:
                seq_input = embedding_dict[feature_name]
            vec = SequencePoolingLayer(combiner, supports_masking=True)(
                seq_input)
        pooling_vec_list[fc.group_name].append(vec)
    if to_list:
        return chain.from_iterable(pooling_vec_list.values())
    return pooling_vec_list

# %%
def mergeDict(a, b):
    c = defaultdict(list)
    for k, v in a.items():
        c[k].extend(v)
    for k, v in b.items():
        c[k].extend(v)
    return c

# %%
class NoMask(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(NoMask, self).__init__(**kwargs)

    def build(self, input_shape):
        # Be sure to call this somewhere!
        super(NoMask, self).build(input_shape)

    def call(self, x, mask=None, **kwargs):
        return x

    def compute_mask(self, inputs, mask):
        return None

# %%
class Linear(tf.keras.layers.Layer):

    def __init__(self, l2_reg=0.0, mode=0, use_bias=False, seed=1024, **kwargs):

        self.l2_reg = l2_reg
        # self.l2_reg = tf.contrib.layers.l2_regularizer(float(l2_reg_linear))
        if mode not in [0, 1, 2]:
            raise ValueError("mode must be 0,1 or 2")
        self.mode = mode
        self.use_bias = use_bias
        self.seed = seed
        super(Linear, self).__init__(**kwargs)

    def build(self, input_shape):
        if self.use_bias:
            self.bias = self.add_weight(name='linear_bias',
                                        shape=(1,),
                                        initializer=tf.keras.initializers.Zeros(),
                                        trainable=True)
        if self.mode == 1:
            self.kernel = self.add_weight(
                'linear_kernel',
                shape=[int(input_shape[-1]), 1],
                initializer=tf.keras.initializers.glorot_normal(self.seed),
                regularizer=tf.keras.regularizers.l2(self.l2_reg),
                trainable=True)
        elif self.mode == 2:
            self.kernel = self.add_weight(
                'linear_kernel',
                shape=[int(input_shape[1][-1]), 1],
                initializer=tf.keras.initializers.glorot_normal(self.seed),
                regularizer=tf.keras.regularizers.l2(self.l2_reg),
                trainable=True)

        super(Linear, self).build(input_shape)  # Be sure to call this somewhere!

    def call(self, inputs, **kwargs):
        if self.mode == 0:
            sparse_input = inputs
            linear_logit = reduce_sum(sparse_input, axis=-1, keep_dims=True)
        elif self.mode == 1:
            dense_input = inputs
            fc = tf.tensordot(dense_input, self.kernel, axes=(-1, 0))
            linear_logit = fc
        else:
            sparse_input, dense_input = inputs
            fc = tf.tensordot(dense_input, self.kernel, axes=(-1, 0))
            linear_logit = reduce_sum(sparse_input, axis=-1, keep_dims=False) + fc
        if self.use_bias:
            linear_logit += self.bias

        return linear_logit

    def compute_output_shape(self, input_shape):
        return (None, 1)

    def compute_mask(self, inputs, mask):
        return None

    def get_config(self, ):
        config = {'mode': self.mode, 'l2_reg': self.l2_reg, 'use_bias': self.use_bias, 'seed': self.seed}
        base_config = super(Linear, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
try:
    unicode
except NameError:
    unicode = str

# %%
class Add(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(Add, self).__init__(**kwargs)

    def build(self, input_shape):
        # Be sure to call this somewhere!
        super(Add, self).build(input_shape)

    def call(self, inputs, **kwargs):
        if not isinstance(inputs, list):
            return inputs
        if len(inputs) == 1:
            return inputs[0]
        if len(inputs) == 0:
            return tf.constant([[0.0]])

        return tf.keras.layers.add(inputs)

# %%
def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

# %%
data = pd.read_csv(r"D:\article\NFM\movielens_sample.txt")
sparse_features = ["movie_id", "user_id","gender", "age", "occupation", "zip"]
target = ['rating']

# 1.Label Encoding for sparse features,and do simple Transformation for dense features
for feat in sparse_features:
    lbe = LabelEncoder()
    data[feat] = lbe.fit_transform(data[feat])
# 2.count #unique features for each sparse field
fixlen_feature_columns = [SparseFeat(feat, data[feat].nunique(),embedding_dim=4)
                          for feat in sparse_features]
linear_feature_columns = fixlen_feature_columns
dnn_feature_columns = fixlen_feature_columns
feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

# 3.generate input data for model
train, test = train_test_split(data, test_size=0.2, random_state=2020)
train_model_input = {name:train[name].values for name in feature_names}
test_model_input = {name:test[name].values for name in feature_names}

# 4.Define Model,train,predict and evaluate
model = NFM(linear_feature_columns, dnn_feature_columns, task='regression')
model.compile(optimizer="adagrad", loss=rmse, metrics=[rmse], )

#history = 
model.fit(train_model_input, train[target].values,
                    batch_size=256, epochs=700, verbose=2, validation_split=0.2, )
# Out:
# WARNING:tensorflow:From C:\Users\moham\anaconda3\lib\site-packages\tensorflow\python\keras\initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/700
# C:\Users\moham\anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1/1 - 0s - loss: 3.6625 - rmse: 3.6625 - val_loss: 3.9633 - val_rmse: 3.9633
# Epoch 2/700
# 1/1 - 0s - loss: 3.6467 - rmse: 3.6467 - val_loss: 3.9509 - val_rmse: 3.9509
# Epoch 3/700
# 1/1 - 0s - loss: 3.6325 - rmse: 3.6325 - val_loss: 3.9410 - val_rmse: 3.9410
# Epoch 4/700
# 1/1 - 0s - loss: 3.6211 - rmse: 3.6211 - val_loss: 3.9323 - val_rmse: 3.9323
# Epoch 5/700
# 1/1 - 0s - loss: 3.6111 - rmse: 3.6111 - val_loss: 3.9242 - val_rmse: 3.9242
# Epoch 6/700
# 1/1 - 0s - loss: 3.6019 - rmse: 3.6019 - val_loss: 3.9167 - val_rmse: 3.9167
# Epoch 7/700
# 1/1 - 0s - loss: 3.5932 - rmse: 3.5932 - val_loss: 3.9094 - val_rmse: 3.9094
# Epoch 8/700
# 1/1 - 0s - loss: 3.5850 - rmse: 3.5850 - val_loss: 3.9024 - val_rmse: 3.9024
# Epoch 9/700
# 1/1 - 0s - loss: 3.5770 - rmse: 3.5770 - val_loss: 3.8957 - val_rmse: 3.8957
# Epoch 10/700
# 1/1 - 0s - loss: 3.5694 - rmse: 3.5694 - val_loss: 3.8891 - val_rmse: 3.8891
# Epoch 11/700
# 1/1 - 0s - loss: 3.5620 - rmse: 3.5620 - val_loss: 3.8827 - val_rmse: 3.8827
# Epoch 12/700
# 1/1 - 0s - loss: 3.5547 - rmse: 3.5547 - val_loss: 3.8763 - val_rmse: 3.8763
# Epoch 13/700
# 1/1 - 0s - loss: 3.5476 - rmse: 3.5476 - val_loss: 3.8701 - val_rmse: 3.8701
# Epoch 14/700
# 1/1 - 0s - loss: 3.5407 - rmse: 3.5407 - val_loss: 3.8640 - val_rmse: 3.8640
# Epoch 15/700
# 1/1 - 0s - loss: 3.5338 - rmse: 3.5338 - val_loss: 3.8580 - val_rmse: 3.8580
# Epoch 16/700
# 1/1 - 0s - loss: 3.5270 - rmse: 3.5270 - val_loss: 3.8519 - val_rmse: 3.8519
# Epoch 17/700
# 1/1 - 0s - loss: 3.5203 - rmse: 3.5203 - val_loss: 3.8461 - val_rmse: 3.8461
# Epoch 18/700
# 1/1 - 0s - loss: 3.5137 - rmse: 3.5137 - val_loss: 3.8402 - val_rmse: 3.8402
# Epoch 19/700
# 1/1 - 0s - loss: 3.5072 - rmse: 3.5072 - val_loss: 3.8344 - val_rmse: 3.8344
# Epoch 20/700
# 1/1 - 0s - loss: 3.5008 - rmse: 3.5008 - val_loss: 3.8287 - val_rmse: 3.8287
# Epoch 21/700
# 1/1 - 0s - loss: 3.4944 - rmse: 3.4944 - val_loss: 3.8229 - val_rmse: 3.8229
# Epoch 22/700
# 1/1 - 0s - loss: 3.4880 - rmse: 3.4880 - val_loss: 3.8172 - val_rmse: 3.8172
# Epoch 23/700
# 1/1 - 0s - loss: 3.4817 - rmse: 3.4817 - val_loss: 3.8116 - val_rmse: 3.8116
# Epoch 24/700
# 1/1 - 0s - loss: 3.4754 - rmse: 3.4754 - val_loss: 3.8060 - val_rmse: 3.8060
# Epoch 25/700
# 1/1 - 0s - loss: 3.4692 - rmse: 3.4692 - val_loss: 3.8004 - val_rmse: 3.8004
# Epoch 26/700
# 1/1 - 0s - loss: 3.4630 - rmse: 3.4630 - val_loss: 3.7949 - val_rmse: 3.7949
# Epoch 27/700
# 1/1 - 0s - loss: 3.4569 - rmse: 3.4569 - val_loss: 3.7893 - val_rmse: 3.7893
# Epoch 28/700
# 1/1 - 0s - loss: 3.4508 - rmse: 3.4508 - val_loss: 3.7838 - val_rmse: 3.7838
# Epoch 29/700
# 1/1 - 0s - loss: 3.4447 - rmse: 3.4447 - val_loss: 3.7784 - val_rmse: 3.7784
# Epoch 30/700
# 1/1 - 0s - loss: 3.4386 - rmse: 3.4386 - val_loss: 3.7729 - val_rmse: 3.7729
# Epoch 31/700
# 1/1 - 0s - loss: 3.4325 - rmse: 3.4325 - val_loss: 3.7674 - val_rmse: 3.7674
# Epoch 32/700
# 1/1 - 0s - loss: 3.4264 - rmse: 3.4264 - val_loss: 3.7620 - val_rmse: 3.7619
# Epoch 33/700
# 1/1 - 0s - loss: 3.4204 - rmse: 3.4204 - val_loss: 3.7565 - val_rmse: 3.7565
# Epoch 34/700
# 1/1 - 0s - loss: 3.4143 - rmse: 3.4143 - val_loss: 3.7510 - val_rmse: 3.7510
# Epoch 35/700
# 1/1 - 0s - loss: 3.4082 - rmse: 3.4082 - val_loss: 3.7455 - val_rmse: 3.7455
# Epoch 36/700
# 1/1 - 0s - loss: 3.4021 - rmse: 3.4021 - val_loss: 3.7401 - val_rmse: 3.7401
# Epoch 37/700
# 1/1 - 0s - loss: 3.3960 - rmse: 3.3960 - val_loss: 3.7345 - val_rmse: 3.7345
# Epoch 38/700
# 1/1 - 0s - loss: 3.3899 - rmse: 3.3899 - val_loss: 3.7290 - val_rmse: 3.7290
# Epoch 39/700
# 1/1 - 0s - loss: 3.3838 - rmse: 3.3838 - val_loss: 3.7234 - val_rmse: 3.7234
# Epoch 40/700
# 1/1 - 0s - loss: 3.3776 - rmse: 3.3776 - val_loss: 3.7178 - val_rmse: 3.7178
# Epoch 41/700
# 1/1 - 0s - loss: 3.3713 - rmse: 3.3713 - val_loss: 3.7123 - val_rmse: 3.7123
# Epoch 42/700
# 1/1 - 0s - loss: 3.3651 - rmse: 3.3651 - val_loss: 3.7067 - val_rmse: 3.7067
# Epoch 43/700
# 1/1 - 0s - loss: 3.3589 - rmse: 3.3589 - val_loss: 3.7010 - val_rmse: 3.7010
# Epoch 44/700
# 1/1 - 0s - loss: 3.3526 - rmse: 3.3526 - val_loss: 3.6954 - val_rmse: 3.6954
# Epoch 45/700
# 1/1 - 0s - loss: 3.3464 - rmse: 3.3464 - val_loss: 3.6898 - val_rmse: 3.6898
# Epoch 46/700
# 1/1 - 0s - loss: 3.3401 - rmse: 3.3401 - val_loss: 3.6842 - val_rmse: 3.6842
# Epoch 47/700
# 1/1 - 0s - loss: 3.3339 - rmse: 3.3338 - val_loss: 3.6786 - val_rmse: 3.6786
# Epoch 48/700
# 1/1 - 0s - loss: 3.3276 - rmse: 3.3276 - val_loss: 3.6730 - val_rmse: 3.6730
# Epoch 49/700
# 1/1 - 0s - loss: 3.3213 - rmse: 3.3213 - val_loss: 3.6673 - val_rmse: 3.6673
# Epoch 50/700
# 1/1 - 0s - loss: 3.3150 - rmse: 3.3150 - val_loss: 3.6617 - val_rmse: 3.6617
# Epoch 51/700
# 1/1 - 0s - loss: 3.3087 - rmse: 3.3087 - val_loss: 3.6561 - val_rmse: 3.6560
# Epoch 52/700
# 1/1 - 0s - loss: 3.3023 - rmse: 3.3023 - val_loss: 3.6504 - val_rmse: 3.6504
# Epoch 53/700
# 1/1 - 0s - loss: 3.2960 - rmse: 3.2959 - val_loss: 3.6447 - val_rmse: 3.6447
# Epoch 54/700
# 1/1 - 0s - loss: 3.2896 - rmse: 3.2896 - val_loss: 3.6390 - val_rmse: 3.6390
# Epoch 55/700
# 1/1 - 0s - loss: 3.2832 - rmse: 3.2832 - val_loss: 3.6333 - val_rmse: 3.6333
# Epoch 56/700
# 1/1 - 0s - loss: 3.2767 - rmse: 3.2767 - val_loss: 3.6276 - val_rmse: 3.6276
# Epoch 57/700
# 1/1 - 0s - loss: 3.2703 - rmse: 3.2703 - val_loss: 3.6218 - val_rmse: 3.6218
# Epoch 58/700
# 1/1 - 0s - loss: 3.2639 - rmse: 3.2638 - val_loss: 3.6161 - val_rmse: 3.6161
# Epoch 59/700
# 1/1 - 0s - loss: 3.2574 - rmse: 3.2574 - val_loss: 3.6103 - val_rmse: 3.6103
# Epoch 60/700
# 1/1 - 0s - loss: 3.2509 - rmse: 3.2509 - val_loss: 3.6046 - val_rmse: 3.6046
# Epoch 61/700
# 1/1 - 0s - loss: 3.2445 - rmse: 3.2444 - val_loss: 3.5988 - val_rmse: 3.5988
# Epoch 62/700
# 1/1 - 0s - loss: 3.2379 - rmse: 3.2379 - val_loss: 3.5930 - val_rmse: 3.5930
# Epoch 63/700
# 1/1 - 0s - loss: 3.2314 - rmse: 3.2314 - val_loss: 3.5872 - val_rmse: 3.5872
# Epoch 64/700
# 1/1 - 0s - loss: 3.2249 - rmse: 3.2248 - val_loss: 3.5814 - val_rmse: 3.5814
# Epoch 65/700
# 1/1 - 0s - loss: 3.2183 - rmse: 3.2183 - val_loss: 3.5756 - val_rmse: 3.5756
# Epoch 66/700
# 1/1 - 0s - loss: 3.2117 - rmse: 3.2117 - val_loss: 3.5698 - val_rmse: 3.5698
# Epoch 67/700
# 1/1 - 0s - loss: 3.2051 - rmse: 3.2051 - val_loss: 3.5639 - val_rmse: 3.5639
# Epoch 68/700
# 1/1 - 0s - loss: 3.1985 - rmse: 3.1984 - val_loss: 3.5581 - val_rmse: 3.5581
# Epoch 69/700
# 1/1 - 0s - loss: 3.1918 - rmse: 3.1918 - val_loss: 3.5522 - val_rmse: 3.5522
# Epoch 70/700
# 1/1 - 0s - loss: 3.1851 - rmse: 3.1851 - val_loss: 3.5463 - val_rmse: 3.5463
# Epoch 71/700
# 1/1 - 0s - loss: 3.1784 - rmse: 3.1784 - val_loss: 3.5404 - val_rmse: 3.5404
# Epoch 72/700
# 1/1 - 0s - loss: 3.1716 - rmse: 3.1716 - val_loss: 3.5344 - val_rmse: 3.5344
# Epoch 73/700
# 1/1 - 0s - loss: 3.1648 - rmse: 3.1648 - val_loss: 3.5283 - val_rmse: 3.5283
# Epoch 74/700
# 1/1 - 0s - loss: 3.1580 - rmse: 3.1580 - val_loss: 3.5223 - val_rmse: 3.5223
# Epoch 75/700
# 1/1 - 0s - loss: 3.1511 - rmse: 3.1511 - val_loss: 3.5162 - val_rmse: 3.5162
# Epoch 76/700
# 1/1 - 0s - loss: 3.1442 - rmse: 3.1441 - val_loss: 3.5102 - val_rmse: 3.5102
# Epoch 77/700
# 1/1 - 0s - loss: 3.1372 - rmse: 3.1372 - val_loss: 3.5041 - val_rmse: 3.5041
# Epoch 78/700
# 1/1 - 0s - loss: 3.1303 - rmse: 3.1302 - val_loss: 3.4980 - val_rmse: 3.4980
# Epoch 79/700
# 1/1 - 0s - loss: 3.1233 - rmse: 3.1233 - val_loss: 3.4918 - val_rmse: 3.4918
# Epoch 80/700
# 1/1 - 0s - loss: 3.1163 - rmse: 3.1162 - val_loss: 3.4857 - val_rmse: 3.4857
# Epoch 81/700
# 1/1 - 0s - loss: 3.1092 - rmse: 3.1092 - val_loss: 3.4796 - val_rmse: 3.4796
# Epoch 82/700
# 1/1 - 0s - loss: 3.1022 - rmse: 3.1022 - val_loss: 3.4734 - val_rmse: 3.4734
# Epoch 83/700
# 1/1 - 0s - loss: 3.0950 - rmse: 3.0950 - val_loss: 3.4672 - val_rmse: 3.4672
# Epoch 84/700
# 1/1 - 0s - loss: 3.0879 - rmse: 3.0879 - val_loss: 3.4611 - val_rmse: 3.4610
# Epoch 85/700
# 1/1 - 0s - loss: 3.0807 - rmse: 3.0807 - val_loss: 3.4548 - val_rmse: 3.4548
# Epoch 86/700
# 1/1 - 0s - loss: 3.0735 - rmse: 3.0735 - val_loss: 3.4485 - val_rmse: 3.4485
# Epoch 87/700
# 1/1 - 0s - loss: 3.0663 - rmse: 3.0662 - val_loss: 3.4422 - val_rmse: 3.4422
# Epoch 88/700
# 1/1 - 0s - loss: 3.0590 - rmse: 3.0590 - val_loss: 3.4359 - val_rmse: 3.4359
# Epoch 89/700
# 1/1 - 0s - loss: 3.0517 - rmse: 3.0517 - val_loss: 3.4296 - val_rmse: 3.4296
# Epoch 90/700
# 1/1 - 0s - loss: 3.0443 - rmse: 3.0443 - val_loss: 3.4232 - val_rmse: 3.4232
# Epoch 91/700
# 1/1 - 0s - loss: 3.0370 - rmse: 3.0370 - val_loss: 3.4169 - val_rmse: 3.4169
# Epoch 92/700
# 1/1 - 0s - loss: 3.0296 - rmse: 3.0296 - val_loss: 3.4105 - val_rmse: 3.4105
# Epoch 93/700
# 1/1 - 0s - loss: 3.0221 - rmse: 3.0221 - val_loss: 3.4041 - val_rmse: 3.4041
# Epoch 94/700
# 1/1 - 0s - loss: 3.0147 - rmse: 3.0147 - val_loss: 3.3977 - val_rmse: 3.3977
# Epoch 95/700
# 1/1 - 0s - loss: 3.0072 - rmse: 3.0072 - val_loss: 3.3912 - val_rmse: 3.3912
# Epoch 96/700
# 1/1 - 0s - loss: 2.9996 - rmse: 2.9996 - val_loss: 3.3847 - val_rmse: 3.3847
# Epoch 97/700
# 1/1 - 0s - loss: 2.9921 - rmse: 2.9921 - val_loss: 3.3783 - val_rmse: 3.3782
# Epoch 98/700
# 1/1 - 0s - loss: 2.9845 - rmse: 2.9845 - val_loss: 3.3717 - val_rmse: 3.3717
# Epoch 99/700
# 1/1 - 0s - loss: 2.9769 - rmse: 2.9769 - val_loss: 3.3652 - val_rmse: 3.3652
# Epoch 100/700
# 1/1 - 0s - loss: 2.9693 - rmse: 2.9693 - val_loss: 3.3587 - val_rmse: 3.3587
# Epoch 101/700
# 1/1 - 0s - loss: 2.9616 - rmse: 2.9616 - val_loss: 3.3521 - val_rmse: 3.3521
# Epoch 102/700
# 1/1 - 0s - loss: 2.9540 - rmse: 2.9539 - val_loss: 3.3456 - val_rmse: 3.3456
# Epoch 103/700
# 1/1 - 0s - loss: 2.9463 - rmse: 2.9463 - val_loss: 3.3390 - val_rmse: 3.3390
# Epoch 104/700
# 1/1 - 0s - loss: 2.9385 - rmse: 2.9385 - val_loss: 3.3324 - val_rmse: 3.3324
# Epoch 105/700
# 1/1 - 0s - loss: 2.9307 - rmse: 2.9307 - val_loss: 3.3257 - val_rmse: 3.3257
# Epoch 106/700
# 1/1 - 0s - loss: 2.9229 - rmse: 2.9229 - val_loss: 3.3191 - val_rmse: 3.3191
# Epoch 107/700
# 1/1 - 0s - loss: 2.9151 - rmse: 2.9151 - val_loss: 3.3124 - val_rmse: 3.3124
# Epoch 108/700
# 1/1 - 0s - loss: 2.9072 - rmse: 2.9072 - val_loss: 3.3057 - val_rmse: 3.3057
# Epoch 109/700
# 1/1 - 0s - loss: 2.8993 - rmse: 2.8993 - val_loss: 3.2990 - val_rmse: 3.2990
# Epoch 110/700
# 1/1 - 0s - loss: 2.8914 - rmse: 2.8914 - val_loss: 3.2923 - val_rmse: 3.2923
# Epoch 111/700
# 1/1 - 0s - loss: 2.8835 - rmse: 2.8835 - val_loss: 3.2856 - val_rmse: 3.2855
# Epoch 112/700
# 1/1 - 0s - loss: 2.8755 - rmse: 2.8755 - val_loss: 3.2788 - val_rmse: 3.2788
# Epoch 113/700
# 1/1 - 0s - loss: 2.8676 - rmse: 2.8675 - val_loss: 3.2721 - val_rmse: 3.2720
# Epoch 114/700
# 1/1 - 0s - loss: 2.8595 - rmse: 2.8595 - val_loss: 3.2653 - val_rmse: 3.2652
# Epoch 115/700
# 1/1 - 0s - loss: 2.8514 - rmse: 2.8514 - val_loss: 3.2585 - val_rmse: 3.2584
# Epoch 116/700
# 1/1 - 0s - loss: 2.8433 - rmse: 2.8433 - val_loss: 3.2517 - val_rmse: 3.2516
# Epoch 117/700
# 1/1 - 0s - loss: 2.8352 - rmse: 2.8352 - val_loss: 3.2448 - val_rmse: 3.2448
# Epoch 118/700
# 1/1 - 0s - loss: 2.8271 - rmse: 2.8271 - val_loss: 3.2379 - val_rmse: 3.2379
# Epoch 119/700
# 1/1 - 0s - loss: 2.8189 - rmse: 2.8189 - val_loss: 3.2310 - val_rmse: 3.2310
# Epoch 120/700
# 1/1 - 0s - loss: 2.8107 - rmse: 2.8107 - val_loss: 3.2241 - val_rmse: 3.2241
# Epoch 121/700
# 1/1 - 0s - loss: 2.8024 - rmse: 2.8024 - val_loss: 3.2172 - val_rmse: 3.2171
# Epoch 122/700
# 1/1 - 0s - loss: 2.7942 - rmse: 2.7941 - val_loss: 3.2102 - val_rmse: 3.2102
# Epoch 123/700
# 1/1 - 0s - loss: 2.7859 - rmse: 2.7858 - val_loss: 3.2032 - val_rmse: 3.2032
# Epoch 124/700
# 1/1 - 0s - loss: 2.7775 - rmse: 2.7775 - val_loss: 3.1962 - val_rmse: 3.1962
# Epoch 125/700
# 1/1 - 0s - loss: 2.7692 - rmse: 2.7692 - val_loss: 3.1892 - val_rmse: 3.1892
# Epoch 126/700
# 1/1 - 0s - loss: 2.7608 - rmse: 2.7608 - val_loss: 3.1822 - val_rmse: 3.1822
# Epoch 127/700
# 1/1 - 0s - loss: 2.7524 - rmse: 2.7524 - val_loss: 3.1752 - val_rmse: 3.1752
# Epoch 128/700
# 1/1 - 0s - loss: 2.7440 - rmse: 2.7439 - val_loss: 3.1682 - val_rmse: 3.1682
# Epoch 129/700
# 1/1 - 0s - loss: 2.7355 - rmse: 2.7355 - val_loss: 3.1611 - val_rmse: 3.1611
# Epoch 130/700
# 1/1 - 0s - loss: 2.7270 - rmse: 2.7270 - val_loss: 3.1541 - val_rmse: 3.1541
# Epoch 131/700
# 1/1 - 0s - loss: 2.7185 - rmse: 2.7185 - val_loss: 3.1470 - val_rmse: 3.1470
# Epoch 132/700
# 1/1 - 0s - loss: 2.7099 - rmse: 2.7099 - val_loss: 3.1399 - val_rmse: 3.1399
# Epoch 133/700
# 1/1 - 0s - loss: 2.7013 - rmse: 2.7013 - val_loss: 3.1328 - val_rmse: 3.1328
# Epoch 134/700
# 1/1 - 0s - loss: 2.6927 - rmse: 2.6927 - val_loss: 3.1258 - val_rmse: 3.1257
# Epoch 135/700
# 1/1 - 0s - loss: 2.6841 - rmse: 2.6841 - val_loss: 3.1186 - val_rmse: 3.1186
# Epoch 136/700
# 1/1 - 0s - loss: 2.6754 - rmse: 2.6754 - val_loss: 3.1115 - val_rmse: 3.1115
# Epoch 137/700
# 1/1 - 0s - loss: 2.6668 - rmse: 2.6667 - val_loss: 3.1044 - val_rmse: 3.1044
# Epoch 138/700
# 1/1 - 0s - loss: 2.6581 - rmse: 2.6580 - val_loss: 3.0972 - val_rmse: 3.0972
# Epoch 139/700
# 1/1 - 0s - loss: 2.6493 - rmse: 2.6493 - val_loss: 3.0900 - val_rmse: 3.0900
# Epoch 140/700
# 1/1 - 0s - loss: 2.6406 - rmse: 2.6406 - val_loss: 3.0829 - val_rmse: 3.0828
# Epoch 141/700
# 1/1 - 0s - loss: 2.6318 - rmse: 2.6318 - val_loss: 3.0756 - val_rmse: 3.0756
# Epoch 142/700
# 1/1 - 0s - loss: 2.6230 - rmse: 2.6230 - val_loss: 3.0684 - val_rmse: 3.0684
# Epoch 143/700
# 1/1 - 0s - loss: 2.6142 - rmse: 2.6142 - val_loss: 3.0612 - val_rmse: 3.0611
# Epoch 144/700
# 1/1 - 0s - loss: 2.6053 - rmse: 2.6053 - val_loss: 3.0539 - val_rmse: 3.0539
# Epoch 145/700
# 1/1 - 0s - loss: 2.5964 - rmse: 2.5964 - val_loss: 3.0466 - val_rmse: 3.0466
# Epoch 146/700
# 1/1 - 0s - loss: 2.5875 - rmse: 2.5875 - val_loss: 3.0393 - val_rmse: 3.0392
# Epoch 147/700
# 1/1 - 0s - loss: 2.5785 - rmse: 2.5785 - val_loss: 3.0319 - val_rmse: 3.0319
# Epoch 148/700
# 1/1 - 0s - loss: 2.5695 - rmse: 2.5695 - val_loss: 3.0246 - val_rmse: 3.0246
# Epoch 149/700
# 1/1 - 0s - loss: 2.5605 - rmse: 2.5605 - val_loss: 3.0172 - val_rmse: 3.0172
# Epoch 150/700
# 1/1 - 0s - loss: 2.5515 - rmse: 2.5514 - val_loss: 3.0098 - val_rmse: 3.0098
# Epoch 151/700
# 1/1 - 0s - loss: 2.5424 - rmse: 2.5424 - val_loss: 3.0025 - val_rmse: 3.0024
# Epoch 152/700
# 1/1 - 0s - loss: 2.5333 - rmse: 2.5333 - val_loss: 2.9950 - val_rmse: 2.9950
# Epoch 153/700
# 1/1 - 0s - loss: 2.5242 - rmse: 2.5242 - val_loss: 2.9876 - val_rmse: 2.9876
# Epoch 154/700
# 1/1 - 0s - loss: 2.5151 - rmse: 2.5151 - val_loss: 2.9802 - val_rmse: 2.9802
# Epoch 155/700
# 1/1 - 0s - loss: 2.5060 - rmse: 2.5060 - val_loss: 2.9728 - val_rmse: 2.9727
# Epoch 156/700
# 1/1 - 0s - loss: 2.4968 - rmse: 2.4968 - val_loss: 2.9653 - val_rmse: 2.9653
# Epoch 157/700
# 1/1 - 0s - loss: 2.4877 - rmse: 2.4876 - val_loss: 2.9578 - val_rmse: 2.9578
# Epoch 158/700
# 1/1 - 0s - loss: 2.4785 - rmse: 2.4784 - val_loss: 2.9504 - val_rmse: 2.9503
# Epoch 159/700
# 1/1 - 0s - loss: 2.4693 - rmse: 2.4692 - val_loss: 2.9429 - val_rmse: 2.9429
# Epoch 160/700
# 1/1 - 0s - loss: 2.4601 - rmse: 2.4600 - val_loss: 2.9354 - val_rmse: 2.9354
# Epoch 161/700
# 1/1 - 0s - loss: 2.4508 - rmse: 2.4508 - val_loss: 2.9279 - val_rmse: 2.9279
# Epoch 162/700
# 1/1 - 0s - loss: 2.4416 - rmse: 2.4415 - val_loss: 2.9204 - val_rmse: 2.9204
# Epoch 163/700
# 1/1 - 0s - loss: 2.4323 - rmse: 2.4323 - val_loss: 2.9129 - val_rmse: 2.9129
# Epoch 164/700
# 1/1 - 0s - loss: 2.4230 - rmse: 2.4230 - val_loss: 2.9054 - val_rmse: 2.9053
# Epoch 165/700
# 1/1 - 0s - loss: 2.4137 - rmse: 2.4137 - val_loss: 2.8978 - val_rmse: 2.8978
# Epoch 166/700
# 1/1 - 0s - loss: 2.4044 - rmse: 2.4044 - val_loss: 2.8903 - val_rmse: 2.8903
# Epoch 167/700
# 1/1 - 0s - loss: 2.3951 - rmse: 2.3951 - val_loss: 2.8828 - val_rmse: 2.8827
# Epoch 168/700
# 1/1 - 0s - loss: 2.3858 - rmse: 2.3857 - val_loss: 2.8752 - val_rmse: 2.8752
# Epoch 169/700
# 1/1 - 0s - loss: 2.3764 - rmse: 2.3764 - val_loss: 2.8677 - val_rmse: 2.8677
# Epoch 170/700
# 1/1 - 0s - loss: 2.3671 - rmse: 2.3670 - val_loss: 2.8601 - val_rmse: 2.8601
# Epoch 171/700
# 1/1 - 0s - loss: 2.3577 - rmse: 2.3577 - val_loss: 2.8526 - val_rmse: 2.8525
# Epoch 172/700
# 1/1 - 0s - loss: 2.3483 - rmse: 2.3483 - val_loss: 2.8450 - val_rmse: 2.8450
# Epoch 173/700
# 1/1 - 0s - loss: 2.3389 - rmse: 2.3389 - val_loss: 2.8374 - val_rmse: 2.8374
# Epoch 174/700
# 1/1 - 0s - loss: 2.3295 - rmse: 2.3294 - val_loss: 2.8299 - val_rmse: 2.8298
# Epoch 175/700
# 1/1 - 0s - loss: 2.3201 - rmse: 2.3200 - val_loss: 2.8223 - val_rmse: 2.8222
# Epoch 176/700
# 1/1 - 0s - loss: 2.3106 - rmse: 2.3106 - val_loss: 2.8147 - val_rmse: 2.8146
# Epoch 177/700
# 1/1 - 0s - loss: 2.3012 - rmse: 2.3011 - val_loss: 2.8071 - val_rmse: 2.8070
# Epoch 178/700
# 1/1 - 0s - loss: 2.2917 - rmse: 2.2917 - val_loss: 2.7995 - val_rmse: 2.7995
# Epoch 179/700
# 1/1 - 0s - loss: 2.2822 - rmse: 2.2822 - val_loss: 2.7919 - val_rmse: 2.7919
# Epoch 180/700
# 1/1 - 0s - loss: 2.2728 - rmse: 2.2727 - val_loss: 2.7843 - val_rmse: 2.7842
# Epoch 181/700
# 1/1 - 0s - loss: 2.2633 - rmse: 2.2632 - val_loss: 2.7767 - val_rmse: 2.7766
# Epoch 182/700
# 1/1 - 0s - loss: 2.2537 - rmse: 2.2537 - val_loss: 2.7691 - val_rmse: 2.7690
# Epoch 183/700
# 1/1 - 0s - loss: 2.2442 - rmse: 2.2442 - val_loss: 2.7615 - val_rmse: 2.7614
# Epoch 184/700
# 1/1 - 0s - loss: 2.2347 - rmse: 2.2346 - val_loss: 2.7538 - val_rmse: 2.7538
# Epoch 185/700
# 1/1 - 0s - loss: 2.2251 - rmse: 2.2250 - val_loss: 2.7462 - val_rmse: 2.7462
# Epoch 186/700
# 1/1 - 0s - loss: 2.2155 - rmse: 2.2155 - val_loss: 2.7386 - val_rmse: 2.7385
# Epoch 187/700
# 1/1 - 0s - loss: 2.2059 - rmse: 2.2059 - val_loss: 2.7309 - val_rmse: 2.7309
# Epoch 188/700
# 1/1 - 0s - loss: 2.1963 - rmse: 2.1963 - val_loss: 2.7233 - val_rmse: 2.7233
# Epoch 189/700
# 1/1 - 0s - loss: 2.1867 - rmse: 2.1867 - val_loss: 2.7157 - val_rmse: 2.7156
# Epoch 190/700
# 1/1 - 0s - loss: 2.1771 - rmse: 2.1770 - val_loss: 2.7080 - val_rmse: 2.7080
# Epoch 191/700
# 1/1 - 0s - loss: 2.1674 - rmse: 2.1674 - val_loss: 2.7004 - val_rmse: 2.7004
# Epoch 192/700
# 1/1 - 0s - loss: 2.1578 - rmse: 2.1577 - val_loss: 2.6928 - val_rmse: 2.6927
# Epoch 193/700
# 1/1 - 0s - loss: 2.1481 - rmse: 2.1481 - val_loss: 2.6851 - val_rmse: 2.6851
# Epoch 194/700
# 1/1 - 0s - loss: 2.1385 - rmse: 2.1384 - val_loss: 2.6774 - val_rmse: 2.6774
# Epoch 195/700
# 1/1 - 0s - loss: 2.1288 - rmse: 2.1288 - val_loss: 2.6698 - val_rmse: 2.6698
# Epoch 196/700
# 1/1 - 0s - loss: 2.1191 - rmse: 2.1191 - val_loss: 2.6621 - val_rmse: 2.6621
# Epoch 197/700
# 1/1 - 0s - loss: 2.1093 - rmse: 2.1092 - val_loss: 2.6545 - val_rmse: 2.6544
# Epoch 198/700
# 1/1 - 0s - loss: 2.0993 - rmse: 2.0992 - val_loss: 2.6468 - val_rmse: 2.6467
# Epoch 199/700
# 1/1 - 0s - loss: 2.0894 - rmse: 2.0893 - val_loss: 2.6391 - val_rmse: 2.6390
# Epoch 200/700
# 1/1 - 0s - loss: 2.0795 - rmse: 2.0795 - val_loss: 2.6312 - val_rmse: 2.6312
# Epoch 201/700
# 1/1 - 0s - loss: 2.0696 - rmse: 2.0696 - val_loss: 2.6234 - val_rmse: 2.6234
# Epoch 202/700
# 1/1 - 0s - loss: 2.0598 - rmse: 2.0597 - val_loss: 2.6156 - val_rmse: 2.6156
# Epoch 203/700
# 1/1 - 0s - loss: 2.0499 - rmse: 2.0499 - val_loss: 2.6078 - val_rmse: 2.6078
# Epoch 204/700
# 1/1 - 0s - loss: 2.0401 - rmse: 2.0401 - val_loss: 2.6000 - val_rmse: 2.6000
# Epoch 205/700
# 1/1 - 0s - loss: 2.0303 - rmse: 2.0302 - val_loss: 2.5922 - val_rmse: 2.5922
# Epoch 206/700
# 1/1 - 0s - loss: 2.0204 - rmse: 2.0204 - val_loss: 2.5845 - val_rmse: 2.5844
# Epoch 207/700
# 1/1 - 0s - loss: 2.0106 - rmse: 2.0105 - val_loss: 2.5767 - val_rmse: 2.5766
# Epoch 208/700
# 1/1 - 0s - loss: 2.0007 - rmse: 2.0007 - val_loss: 2.5689 - val_rmse: 2.5688
# Epoch 209/700
# 1/1 - 0s - loss: 1.9909 - rmse: 1.9909 - val_loss: 2.5611 - val_rmse: 2.5611
# Epoch 210/700
# 1/1 - 0s - loss: 1.9811 - rmse: 1.9810 - val_loss: 2.5534 - val_rmse: 2.5533
# Epoch 211/700
# 1/1 - 0s - loss: 1.9712 - rmse: 1.9712 - val_loss: 2.5456 - val_rmse: 2.5455
# Epoch 212/700
# 1/1 - 0s - loss: 1.9614 - rmse: 1.9614 - val_loss: 2.5378 - val_rmse: 2.5378
# Epoch 213/700
# 1/1 - 0s - loss: 1.9516 - rmse: 1.9516 - val_loss: 2.5300 - val_rmse: 2.5300
# Epoch 214/700
# 1/1 - 0s - loss: 1.9418 - rmse: 1.9417 - val_loss: 2.5223 - val_rmse: 2.5222
# Epoch 215/700
# 1/1 - 0s - loss: 1.9320 - rmse: 1.9319 - val_loss: 2.5145 - val_rmse: 2.5145
# Epoch 216/700
# 1/1 - 0s - loss: 1.9222 - rmse: 1.9221 - val_loss: 2.5068 - val_rmse: 2.5067
# Epoch 217/700
# 1/1 - 0s - loss: 1.9123 - rmse: 1.9123 - val_loss: 2.4990 - val_rmse: 2.4990
# Epoch 218/700
# 1/1 - 0s - loss: 1.9025 - rmse: 1.9025 - val_loss: 2.4913 - val_rmse: 2.4913
# Epoch 219/700
# 1/1 - 0s - loss: 1.8927 - rmse: 1.8927 - val_loss: 2.4836 - val_rmse: 2.4835
# Epoch 220/700
# 1/1 - 0s - loss: 1.8830 - rmse: 1.8829 - val_loss: 2.4758 - val_rmse: 2.4758
# Epoch 221/700
# 1/1 - 0s - loss: 1.8732 - rmse: 1.8731 - val_loss: 2.4681 - val_rmse: 2.4681
# Epoch 222/700
# 1/1 - 0s - loss: 1.8634 - rmse: 1.8634 - val_loss: 2.4604 - val_rmse: 2.4604
# Epoch 223/700
# 1/1 - 0s - loss: 1.8536 - rmse: 1.8536 - val_loss: 2.4527 - val_rmse: 2.4527
# Epoch 224/700
# 1/1 - 0s - loss: 1.8439 - rmse: 1.8438 - val_loss: 2.4450 - val_rmse: 2.4450
# Epoch 225/700
# 1/1 - 0s - loss: 1.8341 - rmse: 1.8341 - val_loss: 2.4373 - val_rmse: 2.4373
# Epoch 226/700
# 1/1 - 0s - loss: 1.8244 - rmse: 1.8243 - val_loss: 2.4296 - val_rmse: 2.4296
# Epoch 227/700
# 1/1 - 0s - loss: 1.8147 - rmse: 1.8146 - val_loss: 2.4219 - val_rmse: 2.4219
# Epoch 228/700
# 1/1 - 0s - loss: 1.8049 - rmse: 1.8049 - val_loss: 2.4143 - val_rmse: 2.4142
# Epoch 229/700
# 1/1 - 0s - loss: 1.7952 - rmse: 1.7952 - val_loss: 2.4066 - val_rmse: 2.4065
# Epoch 230/700
# 1/1 - 0s - loss: 1.7855 - rmse: 1.7855 - val_loss: 2.3990 - val_rmse: 2.3989
# Epoch 231/700
# 1/1 - 0s - loss: 1.7758 - rmse: 1.7758 - val_loss: 2.3913 - val_rmse: 2.3912
# Epoch 232/700
# 1/1 - 0s - loss: 1.7662 - rmse: 1.7661 - val_loss: 2.3837 - val_rmse: 2.3836
# Epoch 233/700
# 1/1 - 0s - loss: 1.7565 - rmse: 1.7565 - val_loss: 2.3760 - val_rmse: 2.3760
# Epoch 234/700
# 1/1 - 0s - loss: 1.7469 - rmse: 1.7468 - val_loss: 2.3684 - val_rmse: 2.3684
# Epoch 235/700
# 1/1 - 0s - loss: 1.7372 - rmse: 1.7372 - val_loss: 2.3608 - val_rmse: 2.3608
# Epoch 236/700
# 1/1 - 0s - loss: 1.7276 - rmse: 1.7276 - val_loss: 2.3532 - val_rmse: 2.3532
# Epoch 237/700
# 1/1 - 0s - loss: 1.7180 - rmse: 1.7180 - val_loss: 2.3456 - val_rmse: 2.3456
# Epoch 238/700
# 1/1 - 0s - loss: 1.7084 - rmse: 1.7084 - val_loss: 2.3381 - val_rmse: 2.3380
# Epoch 239/700
# 1/1 - 0s - loss: 1.6988 - rmse: 1.6988 - val_loss: 2.3305 - val_rmse: 2.3304
# Epoch 240/700
# 1/1 - 0s - loss: 1.6893 - rmse: 1.6892 - val_loss: 2.3229 - val_rmse: 2.3229
# Epoch 241/700
# 1/1 - 0s - loss: 1.6797 - rmse: 1.6797 - val_loss: 2.3154 - val_rmse: 2.3154
# Epoch 242/700
# 1/1 - 0s - loss: 1.6702 - rmse: 1.6701 - val_loss: 2.3079 - val_rmse: 2.3078
# Epoch 243/700
# 1/1 - 0s - loss: 1.6606 - rmse: 1.6606 - val_loss: 2.3004 - val_rmse: 2.3003
# Epoch 244/700
# 1/1 - 0s - loss: 1.6511 - rmse: 1.6511 - val_loss: 2.2929 - val_rmse: 2.2928
# Epoch 245/700
# 1/1 - 0s - loss: 1.6416 - rmse: 1.6416 - val_loss: 2.2854 - val_rmse: 2.2854
# Epoch 246/700
# 1/1 - 0s - loss: 1.6322 - rmse: 1.6321 - val_loss: 2.2779 - val_rmse: 2.2779
# Epoch 247/700
# 1/1 - 0s - loss: 1.6227 - rmse: 1.6226 - val_loss: 2.2705 - val_rmse: 2.2705
# Epoch 248/700
# 1/1 - 0s - loss: 1.6133 - rmse: 1.6132 - val_loss: 2.2631 - val_rmse: 2.2631
# Epoch 249/700
# 1/1 - 0s - loss: 1.6038 - rmse: 1.6038 - val_loss: 2.2555 - val_rmse: 2.2555
# Epoch 250/700
# 1/1 - 0s - loss: 1.5944 - rmse: 1.5944 - val_loss: 2.2482 - val_rmse: 2.2481
# Epoch 251/700
# 1/1 - 0s - loss: 1.5851 - rmse: 1.5850 - val_loss: 2.2408 - val_rmse: 2.2407
# Epoch 252/700
# 1/1 - 0s - loss: 1.5757 - rmse: 1.5757 - val_loss: 2.2334 - val_rmse: 2.2333
# Epoch 253/700
# 1/1 - 0s - loss: 1.5664 - rmse: 1.5663 - val_loss: 2.2261 - val_rmse: 2.2260
# Epoch 254/700
# 1/1 - 0s - loss: 1.5571 - rmse: 1.5570 - val_loss: 2.2187 - val_rmse: 2.2186
# Epoch 255/700
# 1/1 - 0s - loss: 1.5478 - rmse: 1.5477 - val_loss: 2.2114 - val_rmse: 2.2113
# Epoch 256/700
# 1/1 - 0s - loss: 1.5385 - rmse: 1.5384 - val_loss: 2.2041 - val_rmse: 2.2040
# Epoch 257/700
# 1/1 - 0s - loss: 1.5293 - rmse: 1.5292 - val_loss: 2.1968 - val_rmse: 2.1967
# Epoch 258/700
# 1/1 - 0s - loss: 1.5200 - rmse: 1.5200 - val_loss: 2.1895 - val_rmse: 2.1894
# Epoch 259/700
# 1/1 - 0s - loss: 1.5109 - rmse: 1.5108 - val_loss: 2.1822 - val_rmse: 2.1821
# Epoch 260/700
# 1/1 - 0s - loss: 1.5017 - rmse: 1.5016 - val_loss: 2.1749 - val_rmse: 2.1749
# Epoch 261/700
# 1/1 - 0s - loss: 1.4926 - rmse: 1.4925 - val_loss: 2.1677 - val_rmse: 2.1676
# Epoch 262/700
# 1/1 - 0s - loss: 1.4835 - rmse: 1.4834 - val_loss: 2.1605 - val_rmse: 2.1605
# Epoch 263/700
# 1/1 - 0s - loss: 1.4744 - rmse: 1.4744 - val_loss: 2.1534 - val_rmse: 2.1533
# Epoch 264/700
# 1/1 - 0s - loss: 1.4654 - rmse: 1.4653 - val_loss: 2.1461 - val_rmse: 2.1461
# Epoch 265/700
# 1/1 - 0s - loss: 1.4564 - rmse: 1.4563 - val_loss: 2.1390 - val_rmse: 2.1390
# Epoch 266/700
# 1/1 - 0s - loss: 1.4474 - rmse: 1.4474 - val_loss: 2.1319 - val_rmse: 2.1319
# Epoch 267/700
# 1/1 - 0s - loss: 1.4385 - rmse: 1.4385 - val_loss: 2.1248 - val_rmse: 2.1248
# Epoch 268/700
# 1/1 - 0s - loss: 1.4296 - rmse: 1.4296 - val_loss: 2.1177 - val_rmse: 2.1177
# Epoch 269/700
# 1/1 - 0s - loss: 1.4208 - rmse: 1.4207 - val_loss: 2.1107 - val_rmse: 2.1107
# Epoch 270/700
# 1/1 - 0s - loss: 1.4120 - rmse: 1.4119 - val_loss: 2.1038 - val_rmse: 2.1037
# Epoch 271/700
# 1/1 - 0s - loss: 1.4032 - rmse: 1.4032 - val_loss: 2.0968 - val_rmse: 2.0968
# Epoch 272/700
# 1/1 - 0s - loss: 1.3945 - rmse: 1.3944 - val_loss: 2.0899 - val_rmse: 2.0899
# Epoch 273/700
# 1/1 - 0s - loss: 1.3858 - rmse: 1.3858 - val_loss: 2.0827 - val_rmse: 2.0827
# Epoch 274/700
# 1/1 - 0s - loss: 1.3772 - rmse: 1.3771 - val_loss: 2.0759 - val_rmse: 2.0758
# Epoch 275/700
# 1/1 - 0s - loss: 1.3686 - rmse: 1.3685 - val_loss: 2.0690 - val_rmse: 2.0690
# Epoch 276/700
# 1/1 - 0s - loss: 1.3601 - rmse: 1.3600 - val_loss: 2.0622 - val_rmse: 2.0621
# Epoch 277/700
# 1/1 - 0s - loss: 1.3516 - rmse: 1.3515 - val_loss: 2.0554 - val_rmse: 2.0554
# Epoch 278/700
# 1/1 - 0s - loss: 1.3431 - rmse: 1.3431 - val_loss: 2.0486 - val_rmse: 2.0485
# Epoch 279/700
# 1/1 - 0s - loss: 1.3347 - rmse: 1.3347 - val_loss: 2.0419 - val_rmse: 2.0418
# Epoch 280/700
# 1/1 - 0s - loss: 1.3264 - rmse: 1.3263 - val_loss: 2.0352 - val_rmse: 2.0352
# Epoch 281/700
# 1/1 - 0s - loss: 1.3181 - rmse: 1.3180 - val_loss: 2.0288 - val_rmse: 2.0287
# Epoch 282/700
# 1/1 - 0s - loss: 1.3099 - rmse: 1.3098 - val_loss: 2.0221 - val_rmse: 2.0221
# Epoch 283/700
# 1/1 - 0s - loss: 1.3016 - rmse: 1.3015 - val_loss: 2.0155 - val_rmse: 2.0154
# Epoch 284/700
# 1/1 - 0s - loss: 1.2934 - rmse: 1.2934 - val_loss: 2.0089 - val_rmse: 2.0089
# Epoch 285/700
# 1/1 - 0s - loss: 1.2853 - rmse: 1.2853 - val_loss: 2.0021 - val_rmse: 2.0020
# Epoch 286/700
# 1/1 - 0s - loss: 1.2773 - rmse: 1.2772 - val_loss: 1.9956 - val_rmse: 1.9955
# Epoch 287/700
# 1/1 - 0s - loss: 1.2692 - rmse: 1.2692 - val_loss: 1.9891 - val_rmse: 1.9890
# Epoch 288/700
# 1/1 - 0s - loss: 1.2613 - rmse: 1.2612 - val_loss: 1.9827 - val_rmse: 1.9826
# Epoch 289/700
# 1/1 - 0s - loss: 1.2534 - rmse: 1.2533 - val_loss: 1.9763 - val_rmse: 1.9762
# Epoch 290/700
# 1/1 - 0s - loss: 1.2456 - rmse: 1.2455 - val_loss: 1.9700 - val_rmse: 1.9699
# Epoch 291/700
# 1/1 - 0s - loss: 1.2378 - rmse: 1.2377 - val_loss: 1.9639 - val_rmse: 1.9638
# Epoch 292/700
# 1/1 - 0s - loss: 1.2301 - rmse: 1.2300 - val_loss: 1.9582 - val_rmse: 1.9582
# Epoch 293/700
# 1/1 - 0s - loss: 1.2226 - rmse: 1.2226 - val_loss: 1.9514 - val_rmse: 1.9514
# Epoch 294/700
# 1/1 - 0s - loss: 1.2148 - rmse: 1.2148 - val_loss: 1.9454 - val_rmse: 1.9453
# Epoch 295/700
# 1/1 - 0s - loss: 1.2073 - rmse: 1.2072 - val_loss: 1.9393 - val_rmse: 1.9392
# Epoch 296/700
# 1/1 - 0s - loss: 1.1998 - rmse: 1.1998 - val_loss: 1.9333 - val_rmse: 1.9333
# Epoch 297/700
# 1/1 - 0s - loss: 1.1924 - rmse: 1.1924 - val_loss: 1.9274 - val_rmse: 1.9274
# Epoch 298/700
# 1/1 - 0s - loss: 1.1851 - rmse: 1.1850 - val_loss: 1.9214 - val_rmse: 1.9214
# Epoch 299/700
# 1/1 - 0s - loss: 1.1778 - rmse: 1.1777 - val_loss: 1.9157 - val_rmse: 1.9156
# Epoch 300/700
# 1/1 - 0s - loss: 1.1706 - rmse: 1.1705 - val_loss: 1.9091 - val_rmse: 1.9090
# Epoch 301/700
# 1/1 - 0s - loss: 1.1634 - rmse: 1.1634 - val_loss: 1.9033 - val_rmse: 1.9032
# Epoch 302/700
# 1/1 - 0s - loss: 1.1563 - rmse: 1.1563 - val_loss: 1.8974 - val_rmse: 1.8974
# Epoch 303/700
# 1/1 - 0s - loss: 1.1493 - rmse: 1.1493 - val_loss: 1.8917 - val_rmse: 1.8916
# Epoch 304/700
# 1/1 - 0s - loss: 1.1424 - rmse: 1.1423 - val_loss: 1.8858 - val_rmse: 1.8857
# Epoch 305/700
# 1/1 - 0s - loss: 1.1355 - rmse: 1.1354 - val_loss: 1.8802 - val_rmse: 1.8802
# Epoch 306/700
# 1/1 - 0s - loss: 1.1287 - rmse: 1.1286 - val_loss: 1.8745 - val_rmse: 1.8744
# Epoch 307/700
# 1/1 - 0s - loss: 1.1219 - rmse: 1.1219 - val_loss: 1.8689 - val_rmse: 1.8689
# Epoch 308/700
# 1/1 - 0s - loss: 1.1153 - rmse: 1.1152 - val_loss: 1.8631 - val_rmse: 1.8630
# Epoch 309/700
# 1/1 - 0s - loss: 1.1087 - rmse: 1.1087 - val_loss: 1.8574 - val_rmse: 1.8574
# Epoch 310/700
# 1/1 - 0s - loss: 1.1022 - rmse: 1.1022 - val_loss: 1.8520 - val_rmse: 1.8520
# Epoch 311/700
# 1/1 - 0s - loss: 1.0958 - rmse: 1.0957 - val_loss: 1.8466 - val_rmse: 1.8465
# Epoch 312/700
# 1/1 - 0s - loss: 1.0894 - rmse: 1.0894 - val_loss: 1.8414 - val_rmse: 1.8414
# Epoch 313/700
# 1/1 - 0s - loss: 1.0831 - rmse: 1.0831 - val_loss: 1.8359 - val_rmse: 1.8358
# Epoch 314/700
# 1/1 - 0s - loss: 1.0769 - rmse: 1.0769 - val_loss: 1.8308 - val_rmse: 1.8308
# Epoch 315/700
# 1/1 - 0s - loss: 1.0708 - rmse: 1.0708 - val_loss: 1.8253 - val_rmse: 1.8253
# Epoch 316/700
# 1/1 - 0s - loss: 1.0648 - rmse: 1.0647 - val_loss: 1.8202 - val_rmse: 1.8201
# Epoch 317/700
# 1/1 - 0s - loss: 1.0588 - rmse: 1.0588 - val_loss: 1.8150 - val_rmse: 1.8149
# Epoch 318/700
# 1/1 - 0s - loss: 1.0529 - rmse: 1.0528 - val_loss: 1.8101 - val_rmse: 1.8101
# Epoch 319/700
# 1/1 - 0s - loss: 1.0471 - rmse: 1.0470 - val_loss: 1.8050 - val_rmse: 1.8049
# Epoch 320/700
# 1/1 - 0s - loss: 1.0414 - rmse: 1.0413 - val_loss: 1.8001 - val_rmse: 1.8000
# Epoch 321/700
# 1/1 - 0s - loss: 1.0357 - rmse: 1.0356 - val_loss: 1.7950 - val_rmse: 1.7950
# Epoch 322/700
# 1/1 - 0s - loss: 1.0301 - rmse: 1.0301 - val_loss: 1.7903 - val_rmse: 1.7902
# Epoch 323/700
# 1/1 - 0s - loss: 1.0246 - rmse: 1.0245 - val_loss: 1.7856 - val_rmse: 1.7856
# Epoch 324/700
# 1/1 - 0s - loss: 1.0191 - rmse: 1.0191 - val_loss: 1.7808 - val_rmse: 1.7807
# Epoch 325/700
# 1/1 - 0s - loss: 1.0138 - rmse: 1.0137 - val_loss: 1.7762 - val_rmse: 1.7762
# Epoch 326/700
# 1/1 - 0s - loss: 1.0085 - rmse: 1.0084 - val_loss: 1.7719 - val_rmse: 1.7718
# Epoch 327/700
# 1/1 - 0s - loss: 1.0033 - rmse: 1.0032 - val_loss: 1.7671 - val_rmse: 1.7671
# Epoch 328/700
# 1/1 - 0s - loss: 0.9981 - rmse: 0.9981 - val_loss: 1.7626 - val_rmse: 1.7625
# Epoch 329/700
# 1/1 - 0s - loss: 0.9931 - rmse: 0.9930 - val_loss: 1.7585 - val_rmse: 1.7584
# Epoch 330/700
# 1/1 - 0s - loss: 0.9880 - rmse: 0.9879 - val_loss: 1.7545 - val_rmse: 1.7545
# Epoch 331/700
# 1/1 - 0s - loss: 0.9830 - rmse: 0.9829 - val_loss: 1.7502 - val_rmse: 1.7501
# Epoch 332/700
# 1/1 - 0s - loss: 0.9781 - rmse: 0.9780 - val_loss: 1.7459 - val_rmse: 1.7459
# Epoch 333/700
# 1/1 - 0s - loss: 0.9732 - rmse: 0.9732 - val_loss: 1.7421 - val_rmse: 1.7420
# Epoch 334/700
# 1/1 - 0s - loss: 0.9684 - rmse: 0.9683 - val_loss: 1.7382 - val_rmse: 1.7382
# Epoch 335/700
# 1/1 - 0s - loss: 0.9637 - rmse: 0.9636 - val_loss: 1.7341 - val_rmse: 1.7340
# Epoch 336/700
# 1/1 - 0s - loss: 0.9591 - rmse: 0.9590 - val_loss: 1.7302 - val_rmse: 1.7302
# Epoch 337/700
# 1/1 - 0s - loss: 0.9545 - rmse: 0.9544 - val_loss: 1.7266 - val_rmse: 1.7266
# Epoch 338/700
# 1/1 - 0s - loss: 0.9500 - rmse: 0.9499 - val_loss: 1.7225 - val_rmse: 1.7225
# Epoch 339/700
# 1/1 - 0s - loss: 0.9456 - rmse: 0.9455 - val_loss: 1.7192 - val_rmse: 1.7191
# Epoch 340/700
# 1/1 - 0s - loss: 0.9412 - rmse: 0.9411 - val_loss: 1.7151 - val_rmse: 1.7150
# Epoch 341/700
# 1/1 - 0s - loss: 0.9369 - rmse: 0.9368 - val_loss: 1.7117 - val_rmse: 1.7116
# Epoch 342/700
# 1/1 - 0s - loss: 0.9326 - rmse: 0.9325 - val_loss: 1.7083 - val_rmse: 1.7082
# Epoch 343/700
# 1/1 - 0s - loss: 0.9284 - rmse: 0.9283 - val_loss: 1.7046 - val_rmse: 1.7046
# Epoch 344/700
# 1/1 - 0s - loss: 0.9243 - rmse: 0.9242 - val_loss: 1.7013 - val_rmse: 1.7012
# Epoch 345/700
# 1/1 - 0s - loss: 0.9202 - rmse: 0.9201 - val_loss: 1.6980 - val_rmse: 1.6979
# Epoch 346/700
# 1/1 - 0s - loss: 0.9161 - rmse: 0.9161 - val_loss: 1.6944 - val_rmse: 1.6944
# Epoch 347/700
# 1/1 - 0s - loss: 0.9122 - rmse: 0.9121 - val_loss: 1.6915 - val_rmse: 1.6914
# Epoch 348/700
# 1/1 - 0s - loss: 0.9082 - rmse: 0.9082 - val_loss: 1.6882 - val_rmse: 1.6881
# Epoch 349/700
# 1/1 - 0s - loss: 0.9044 - rmse: 0.9043 - val_loss: 1.6848 - val_rmse: 1.6848
# Epoch 350/700
# 1/1 - 0s - loss: 0.9006 - rmse: 0.9005 - val_loss: 1.6820 - val_rmse: 1.6819
# Epoch 351/700
# 1/1 - 0s - loss: 0.8968 - rmse: 0.8968 - val_loss: 1.6787 - val_rmse: 1.6786
# Epoch 352/700
# 1/1 - 0s - loss: 0.8932 - rmse: 0.8931 - val_loss: 1.6759 - val_rmse: 1.6759
# Epoch 353/700
# 1/1 - 0s - loss: 0.8895 - rmse: 0.8894 - val_loss: 1.6730 - val_rmse: 1.6729
# Epoch 354/700
# 1/1 - 0s - loss: 0.8859 - rmse: 0.8858 - val_loss: 1.6705 - val_rmse: 1.6704
# Epoch 355/700
# 1/1 - 0s - loss: 0.8823 - rmse: 0.8822 - val_loss: 1.6680 - val_rmse: 1.6679
# Epoch 356/700
# 1/1 - 0s - loss: 0.8788 - rmse: 0.8787 - val_loss: 1.6652 - val_rmse: 1.6651
# Epoch 357/700
# 1/1 - 0s - loss: 0.8752 - rmse: 0.8751 - val_loss: 1.6625 - val_rmse: 1.6625
# Epoch 358/700
# 1/1 - 0s - loss: 0.8717 - rmse: 0.8717 - val_loss: 1.6600 - val_rmse: 1.6599
# Epoch 359/700
# 1/1 - 0s - loss: 0.8683 - rmse: 0.8683 - val_loss: 1.6575 - val_rmse: 1.6574
# Epoch 360/700
# 1/1 - 0s - loss: 0.8650 - rmse: 0.8649 - val_loss: 1.6553 - val_rmse: 1.6552
# Epoch 361/700
# 1/1 - 0s - loss: 0.8617 - rmse: 0.8616 - val_loss: 1.6527 - val_rmse: 1.6526
# Epoch 362/700
# 1/1 - 0s - loss: 0.8584 - rmse: 0.8583 - val_loss: 1.6507 - val_rmse: 1.6506
# Epoch 363/700
# 1/1 - 0s - loss: 0.8552 - rmse: 0.8551 - val_loss: 1.6480 - val_rmse: 1.6479
# Epoch 364/700
# 1/1 - 0s - loss: 0.8520 - rmse: 0.8519 - val_loss: 1.6463 - val_rmse: 1.6462
# Epoch 365/700
# 1/1 - 0s - loss: 0.8488 - rmse: 0.8487 - val_loss: 1.6438 - val_rmse: 1.6437
# Epoch 366/700
# 1/1 - 0s - loss: 0.8456 - rmse: 0.8456 - val_loss: 1.6421 - val_rmse: 1.6421
# Epoch 367/700
# 1/1 - 0s - loss: 0.8425 - rmse: 0.8425 - val_loss: 1.6397 - val_rmse: 1.6396
# Epoch 368/700
# 1/1 - 0s - loss: 0.8395 - rmse: 0.8394 - val_loss: 1.6381 - val_rmse: 1.6380
# Epoch 369/700
# 1/1 - 0s - loss: 0.8364 - rmse: 0.8364 - val_loss: 1.6358 - val_rmse: 1.6358
# Epoch 370/700
# 1/1 - 0s - loss: 0.8334 - rmse: 0.8334 - val_loss: 1.6342 - val_rmse: 1.6341
# Epoch 371/700
# 1/1 - 0s - loss: 0.8304 - rmse: 0.8303 - val_loss: 1.6320 - val_rmse: 1.6320
# Epoch 372/700
# 1/1 - 0s - loss: 0.8275 - rmse: 0.8274 - val_loss: 1.6303 - val_rmse: 1.6303
# Epoch 373/700
# 1/1 - 0s - loss: 0.8246 - rmse: 0.8246 - val_loss: 1.6283 - val_rmse: 1.6282
# Epoch 374/700
# 1/1 - 0s - loss: 0.8218 - rmse: 0.8217 - val_loss: 1.6268 - val_rmse: 1.6267
# Epoch 375/700
# 1/1 - 0s - loss: 0.8189 - rmse: 0.8188 - val_loss: 1.6249 - val_rmse: 1.6249
# Epoch 376/700
# 1/1 - 0s - loss: 0.8162 - rmse: 0.8161 - val_loss: 1.6233 - val_rmse: 1.6232
# Epoch 377/700
# 1/1 - 0s - loss: 0.8133 - rmse: 0.8133 - val_loss: 1.6214 - val_rmse: 1.6213
# Epoch 378/700
# 1/1 - 0s - loss: 0.8106 - rmse: 0.8105 - val_loss: 1.6200 - val_rmse: 1.6199
# Epoch 379/700
# 1/1 - 0s - loss: 0.8079 - rmse: 0.8078 - val_loss: 1.6182 - val_rmse: 1.6182
# Epoch 380/700
# 1/1 - 0s - loss: 0.8051 - rmse: 0.8051 - val_loss: 1.6170 - val_rmse: 1.6169
# Epoch 381/700
# 1/1 - 0s - loss: 0.8025 - rmse: 0.8024 - val_loss: 1.6153 - val_rmse: 1.6152
# Epoch 382/700
# 1/1 - 0s - loss: 0.7998 - rmse: 0.7997 - val_loss: 1.6141 - val_rmse: 1.6141
# Epoch 383/700
# 1/1 - 0s - loss: 0.7971 - rmse: 0.7971 - val_loss: 1.6125 - val_rmse: 1.6124
# Epoch 384/700
# 1/1 - 0s - loss: 0.7946 - rmse: 0.7945 - val_loss: 1.6114 - val_rmse: 1.6113
# Epoch 385/700
# 1/1 - 0s - loss: 0.7919 - rmse: 0.7919 - val_loss: 1.6098 - val_rmse: 1.6098
# Epoch 386/700
# 1/1 - 0s - loss: 0.7894 - rmse: 0.7893 - val_loss: 1.6088 - val_rmse: 1.6087
# Epoch 387/700
# 1/1 - 0s - loss: 0.7868 - rmse: 0.7867 - val_loss: 1.6074 - val_rmse: 1.6073
# Epoch 388/700
# 1/1 - 0s - loss: 0.7843 - rmse: 0.7842 - val_loss: 1.6065 - val_rmse: 1.6064
# Epoch 389/700
# 1/1 - 0s - loss: 0.7817 - rmse: 0.7817 - val_loss: 1.6051 - val_rmse: 1.6050
# Epoch 390/700
# 1/1 - 0s - loss: 0.7792 - rmse: 0.7792 - val_loss: 1.6043 - val_rmse: 1.6043
# Epoch 391/700
# 1/1 - 0s - loss: 0.7767 - rmse: 0.7767 - val_loss: 1.6031 - val_rmse: 1.6030
# Epoch 392/700
# 1/1 - 0s - loss: 0.7743 - rmse: 0.7742 - val_loss: 1.6024 - val_rmse: 1.6024
# Epoch 393/700
# 1/1 - 0s - loss: 0.7718 - rmse: 0.7718 - val_loss: 1.6013 - val_rmse: 1.6012
# Epoch 394/700
# 1/1 - 0s - loss: 0.7693 - rmse: 0.7693 - val_loss: 1.6006 - val_rmse: 1.6005
# Epoch 395/700
# 1/1 - 0s - loss: 0.7669 - rmse: 0.7668 - val_loss: 1.5997 - val_rmse: 1.5996
# Epoch 396/700
# 1/1 - 0s - loss: 0.7644 - rmse: 0.7644 - val_loss: 1.5992 - val_rmse: 1.5991
# Epoch 397/700
# 1/1 - 0s - loss: 0.7620 - rmse: 0.7619 - val_loss: 1.5983 - val_rmse: 1.5982
# Epoch 398/700
# 1/1 - 0s - loss: 0.7595 - rmse: 0.7595 - val_loss: 1.5980 - val_rmse: 1.5980
# Epoch 399/700
# 1/1 - 0s - loss: 0.7571 - rmse: 0.7570 - val_loss: 1.5971 - val_rmse: 1.5971
# Epoch 400/700
# 1/1 - 0s - loss: 0.7547 - rmse: 0.7546 - val_loss: 1.5969 - val_rmse: 1.5968
# Epoch 401/700
# 1/1 - 0s - loss: 0.7522 - rmse: 0.7522 - val_loss: 1.5962 - val_rmse: 1.5961
# Epoch 402/700
# 1/1 - 0s - loss: 0.7498 - rmse: 0.7498 - val_loss: 1.5960 - val_rmse: 1.5959
# Epoch 403/700
# 1/1 - 0s - loss: 0.7474 - rmse: 0.7473 - val_loss: 1.5955 - val_rmse: 1.5954
# Epoch 404/700
# 1/1 - 0s - loss: 0.7450 - rmse: 0.7449 - val_loss: 1.5954 - val_rmse: 1.5953
# Epoch 405/700
# 1/1 - 0s - loss: 0.7426 - rmse: 0.7425 - val_loss: 1.5951 - val_rmse: 1.5950
# Epoch 406/700
# 1/1 - 0s - loss: 0.7402 - rmse: 0.7401 - val_loss: 1.5950 - val_rmse: 1.5950
# Epoch 407/700
# 1/1 - 0s - loss: 0.7377 - rmse: 0.7376 - val_loss: 1.5948 - val_rmse: 1.5947
# Epoch 408/700
# 1/1 - 0s - loss: 0.7353 - rmse: 0.7352 - val_loss: 1.5950 - val_rmse: 1.5949
# Epoch 409/700
# 1/1 - 0s - loss: 0.7329 - rmse: 0.7328 - val_loss: 1.5948 - val_rmse: 1.5947
# Epoch 410/700
# 1/1 - 0s - loss: 0.7304 - rmse: 0.7303 - val_loss: 1.5950 - val_rmse: 1.5949
# Epoch 411/700
# 1/1 - 0s - loss: 0.7280 - rmse: 0.7279 - val_loss: 1.5950 - val_rmse: 1.5949
# Epoch 412/700
# 1/1 - 0s - loss: 0.7255 - rmse: 0.7255 - val_loss: 1.5952 - val_rmse: 1.5951
# Epoch 413/700
# 1/1 - 0s - loss: 0.7231 - rmse: 0.7230 - val_loss: 1.5952 - val_rmse: 1.5952
# Epoch 414/700
# 1/1 - 0s - loss: 0.7207 - rmse: 0.7206 - val_loss: 1.5955 - val_rmse: 1.5955
# Epoch 415/700
# 1/1 - 0s - loss: 0.7183 - rmse: 0.7182 - val_loss: 1.5955 - val_rmse: 1.5955
# Epoch 416/700
# 1/1 - 0s - loss: 0.7158 - rmse: 0.7158 - val_loss: 1.5960 - val_rmse: 1.5959
# Epoch 417/700
# 1/1 - 0s - loss: 0.7134 - rmse: 0.7134 - val_loss: 1.5960 - val_rmse: 1.5959
# Epoch 418/700
# 1/1 - 0s - loss: 0.7110 - rmse: 0.7109 - val_loss: 1.5965 - val_rmse: 1.5965
# Epoch 419/700
# 1/1 - 0s - loss: 0.7086 - rmse: 0.7085 - val_loss: 1.5966 - val_rmse: 1.5966
# Epoch 420/700
# 1/1 - 0s - loss: 0.7061 - rmse: 0.7061 - val_loss: 1.5972 - val_rmse: 1.5972
# Epoch 421/700
# 1/1 - 0s - loss: 0.7037 - rmse: 0.7036 - val_loss: 1.5974 - val_rmse: 1.5973
# Epoch 422/700
# 1/1 - 0s - loss: 0.7012 - rmse: 0.7012 - val_loss: 1.5981 - val_rmse: 1.5981
# Epoch 423/700
# 1/1 - 0s - loss: 0.6988 - rmse: 0.6987 - val_loss: 1.5983 - val_rmse: 1.5982
# Epoch 424/700
# 1/1 - 0s - loss: 0.6963 - rmse: 0.6962 - val_loss: 1.5990 - val_rmse: 1.5990
# Epoch 425/700
# 1/1 - 0s - loss: 0.6938 - rmse: 0.6937 - val_loss: 1.5994 - val_rmse: 1.5994
# Epoch 426/700
# 1/1 - 0s - loss: 0.6913 - rmse: 0.6912 - val_loss: 1.6001 - val_rmse: 1.6000
# Epoch 427/700
# 1/1 - 0s - loss: 0.6888 - rmse: 0.6887 - val_loss: 1.6004 - val_rmse: 1.6004
# Epoch 428/700
# 1/1 - 0s - loss: 0.6863 - rmse: 0.6862 - val_loss: 1.6013 - val_rmse: 1.6012
# Epoch 429/700
# 1/1 - 0s - loss: 0.6838 - rmse: 0.6838 - val_loss: 1.6016 - val_rmse: 1.6016
# Epoch 430/700
# 1/1 - 0s - loss: 0.6813 - rmse: 0.6813 - val_loss: 1.6025 - val_rmse: 1.6024
# Epoch 431/700
# 1/1 - 0s - loss: 0.6789 - rmse: 0.6788 - val_loss: 1.6030 - val_rmse: 1.6029
# Epoch 432/700
# 1/1 - 0s - loss: 0.6764 - rmse: 0.6763 - val_loss: 1.6038 - val_rmse: 1.6037
# Epoch 433/700
# 1/1 - 0s - loss: 0.6739 - rmse: 0.6738 - val_loss: 1.6043 - val_rmse: 1.6043
# Epoch 434/700
# 1/1 - 0s - loss: 0.6714 - rmse: 0.6713 - val_loss: 1.6052 - val_rmse: 1.6052
# Epoch 435/700
# 1/1 - 0s - loss: 0.6689 - rmse: 0.6688 - val_loss: 1.6058 - val_rmse: 1.6058
# Epoch 436/700
# 1/1 - 0s - loss: 0.6664 - rmse: 0.6664 - val_loss: 1.6066 - val_rmse: 1.6065
# Epoch 437/700
# 1/1 - 0s - loss: 0.6639 - rmse: 0.6639 - val_loss: 1.6072 - val_rmse: 1.6072
# Epoch 438/700
# 1/1 - 0s - loss: 0.6614 - rmse: 0.6614 - val_loss: 1.6081 - val_rmse: 1.6081
# Epoch 439/700
# 1/1 - 0s - loss: 0.6589 - rmse: 0.6589 - val_loss: 1.6091 - val_rmse: 1.6090
# Epoch 440/700
# 1/1 - 0s - loss: 0.6563 - rmse: 0.6563 - val_loss: 1.6103 - val_rmse: 1.6102
# Epoch 441/700
# 1/1 - 0s - loss: 0.6538 - rmse: 0.6538 - val_loss: 1.6110 - val_rmse: 1.6109
# Epoch 442/700
# 1/1 - 0s - loss: 0.6513 - rmse: 0.6512 - val_loss: 1.6119 - val_rmse: 1.6118
# Epoch 443/700
# 1/1 - 0s - loss: 0.6488 - rmse: 0.6487 - val_loss: 1.6124 - val_rmse: 1.6124
# Epoch 444/700
# 1/1 - 0s - loss: 0.6463 - rmse: 0.6462 - val_loss: 1.6135 - val_rmse: 1.6134
# Epoch 445/700
# 1/1 - 0s - loss: 0.6438 - rmse: 0.6438 - val_loss: 1.6141 - val_rmse: 1.6140
# Epoch 446/700
# 1/1 - 0s - loss: 0.6413 - rmse: 0.6413 - val_loss: 1.6149 - val_rmse: 1.6148
# Epoch 447/700
# 1/1 - 0s - loss: 0.6389 - rmse: 0.6388 - val_loss: 1.6158 - val_rmse: 1.6157
# Epoch 448/700
# 1/1 - 0s - loss: 0.6364 - rmse: 0.6363 - val_loss: 1.6168 - val_rmse: 1.6167
# Epoch 449/700
# 1/1 - 0s - loss: 0.6339 - rmse: 0.6338 - val_loss: 1.6174 - val_rmse: 1.6173
# Epoch 450/700
# 1/1 - 0s - loss: 0.6314 - rmse: 0.6313 - val_loss: 1.6183 - val_rmse: 1.6183
# Epoch 451/700
# 1/1 - 0s - loss: 0.6289 - rmse: 0.6288 - val_loss: 1.6191 - val_rmse: 1.6190
# Epoch 452/700
# 1/1 - 0s - loss: 0.6264 - rmse: 0.6264 - val_loss: 1.6199 - val_rmse: 1.6198
# Epoch 453/700
# 1/1 - 0s - loss: 0.6239 - rmse: 0.6239 - val_loss: 1.6206 - val_rmse: 1.6205
# Epoch 454/700
# 1/1 - 0s - loss: 0.6215 - rmse: 0.6214 - val_loss: 1.6216 - val_rmse: 1.6215
# Epoch 455/700
# 1/1 - 0s - loss: 0.6190 - rmse: 0.6189 - val_loss: 1.6225 - val_rmse: 1.6224
# Epoch 456/700
# 1/1 - 0s - loss: 0.6165 - rmse: 0.6164 - val_loss: 1.6233 - val_rmse: 1.6233
# Epoch 457/700
# 1/1 - 0s - loss: 0.6140 - rmse: 0.6140 - val_loss: 1.6242 - val_rmse: 1.6241
# Epoch 458/700
# 1/1 - 0s - loss: 0.6116 - rmse: 0.6115 - val_loss: 1.6251 - val_rmse: 1.6251
# Epoch 459/700
# 1/1 - 0s - loss: 0.6091 - rmse: 0.6090 - val_loss: 1.6261 - val_rmse: 1.6260
# Epoch 460/700
# 1/1 - 0s - loss: 0.6066 - rmse: 0.6066 - val_loss: 1.6270 - val_rmse: 1.6269
# Epoch 461/700
# 1/1 - 0s - loss: 0.6042 - rmse: 0.6041 - val_loss: 1.6281 - val_rmse: 1.6280
# Epoch 462/700
# 1/1 - 0s - loss: 0.6017 - rmse: 0.6016 - val_loss: 1.6290 - val_rmse: 1.6289
# Epoch 463/700
# 1/1 - 0s - loss: 0.5992 - rmse: 0.5991 - val_loss: 1.6300 - val_rmse: 1.6300
# Epoch 464/700
# 1/1 - 0s - loss: 0.5967 - rmse: 0.5967 - val_loss: 1.6310 - val_rmse: 1.6309
# Epoch 465/700
# 1/1 - 0s - loss: 0.5943 - rmse: 0.5942 - val_loss: 1.6322 - val_rmse: 1.6321
# Epoch 466/700
# 1/1 - 0s - loss: 0.5918 - rmse: 0.5917 - val_loss: 1.6331 - val_rmse: 1.6331
# Epoch 467/700
# 1/1 - 0s - loss: 0.5893 - rmse: 0.5892 - val_loss: 1.6343 - val_rmse: 1.6342
# Epoch 468/700
# 1/1 - 0s - loss: 0.5868 - rmse: 0.5867 - val_loss: 1.6353 - val_rmse: 1.6353
# Epoch 469/700
# 1/1 - 0s - loss: 0.5843 - rmse: 0.5842 - val_loss: 1.6365 - val_rmse: 1.6365
# Epoch 470/700
# 1/1 - 0s - loss: 0.5818 - rmse: 0.5818 - val_loss: 1.6376 - val_rmse: 1.6375
# Epoch 471/700
# 1/1 - 0s - loss: 0.5793 - rmse: 0.5792 - val_loss: 1.6388 - val_rmse: 1.6387
# Epoch 472/700
# 1/1 - 0s - loss: 0.5768 - rmse: 0.5767 - val_loss: 1.6401 - val_rmse: 1.6400
# Epoch 473/700
# 1/1 - 0s - loss: 0.5742 - rmse: 0.5742 - val_loss: 1.6411 - val_rmse: 1.6411
# Epoch 474/700
# 1/1 - 0s - loss: 0.5718 - rmse: 0.5717 - val_loss: 1.6426 - val_rmse: 1.6426
# Epoch 475/700
# 1/1 - 0s - loss: 0.5692 - rmse: 0.5691 - val_loss: 1.6436 - val_rmse: 1.6436
# Epoch 476/700
# 1/1 - 0s - loss: 0.5667 - rmse: 0.5666 - val_loss: 1.6451 - val_rmse: 1.6450
# Epoch 477/700
# 1/1 - 0s - loss: 0.5641 - rmse: 0.5640 - val_loss: 1.6463 - val_rmse: 1.6462
# Epoch 478/700
# 1/1 - 0s - loss: 0.5615 - rmse: 0.5615 - val_loss: 1.6479 - val_rmse: 1.6478
# Epoch 479/700
# 1/1 - 0s - loss: 0.5590 - rmse: 0.5589 - val_loss: 1.6489 - val_rmse: 1.6488
# Epoch 480/700
# 1/1 - 0s - loss: 0.5564 - rmse: 0.5564 - val_loss: 1.6500 - val_rmse: 1.6499
# Epoch 481/700
# 1/1 - 0s - loss: 0.5539 - rmse: 0.5538 - val_loss: 1.6521 - val_rmse: 1.6520
# Epoch 482/700
# 1/1 - 0s - loss: 0.5514 - rmse: 0.5513 - val_loss: 1.6533 - val_rmse: 1.6533
# Epoch 483/700
# 1/1 - 0s - loss: 0.5488 - rmse: 0.5487 - val_loss: 1.6543 - val_rmse: 1.6543
# Epoch 484/700
# 1/1 - 0s - loss: 0.5462 - rmse: 0.5461 - val_loss: 1.6557 - val_rmse: 1.6556
# Epoch 485/700
# 1/1 - 0s - loss: 0.5436 - rmse: 0.5435 - val_loss: 1.6570 - val_rmse: 1.6569
# Epoch 486/700
# 1/1 - 0s - loss: 0.5411 - rmse: 0.5410 - val_loss: 1.6584 - val_rmse: 1.6583
# Epoch 487/700
# 1/1 - 0s - loss: 0.5385 - rmse: 0.5385 - val_loss: 1.6596 - val_rmse: 1.6595
# Epoch 488/700
# 1/1 - 0s - loss: 0.5360 - rmse: 0.5359 - val_loss: 1.6607 - val_rmse: 1.6607
# Epoch 489/700
# 1/1 - 0s - loss: 0.5334 - rmse: 0.5333 - val_loss: 1.6627 - val_rmse: 1.6626
# Epoch 490/700
# 1/1 - 0s - loss: 0.5308 - rmse: 0.5307 - val_loss: 1.6639 - val_rmse: 1.6639
# Epoch 491/700
# 1/1 - 0s - loss: 0.5282 - rmse: 0.5281 - val_loss: 1.6653 - val_rmse: 1.6653
# Epoch 492/700
# 1/1 - 0s - loss: 0.5256 - rmse: 0.5256 - val_loss: 1.6666 - val_rmse: 1.6665
# Epoch 493/700
# 1/1 - 0s - loss: 0.5231 - rmse: 0.5230 - val_loss: 1.6678 - val_rmse: 1.6678
# Epoch 494/700
# 1/1 - 0s - loss: 0.5205 - rmse: 0.5204 - val_loss: 1.6689 - val_rmse: 1.6689
# Epoch 495/700
# 1/1 - 0s - loss: 0.5180 - rmse: 0.5179 - val_loss: 1.6708 - val_rmse: 1.6708
# Epoch 496/700
# 1/1 - 0s - loss: 0.5155 - rmse: 0.5154 - val_loss: 1.6719 - val_rmse: 1.6719
# Epoch 497/700
# 1/1 - 0s - loss: 0.5129 - rmse: 0.5128 - val_loss: 1.6730 - val_rmse: 1.6729
# Epoch 498/700
# 1/1 - 0s - loss: 0.5103 - rmse: 0.5103 - val_loss: 1.6744 - val_rmse: 1.6743
# Epoch 499/700
# 1/1 - 0s - loss: 0.5078 - rmse: 0.5078 - val_loss: 1.6759 - val_rmse: 1.6758
# Epoch 500/700
# 1/1 - 0s - loss: 0.5053 - rmse: 0.5052 - val_loss: 1.6770 - val_rmse: 1.6769
# Epoch 501/700
# 1/1 - 0s - loss: 0.5028 - rmse: 0.5027 - val_loss: 1.6784 - val_rmse: 1.6784
# Epoch 502/700
# 1/1 - 0s - loss: 0.5002 - rmse: 0.5002 - val_loss: 1.6799 - val_rmse: 1.6798
# Epoch 503/700
# 1/1 - 0s - loss: 0.4977 - rmse: 0.4976 - val_loss: 1.6811 - val_rmse: 1.6810
# Epoch 504/700
# 1/1 - 0s - loss: 0.4952 - rmse: 0.4951 - val_loss: 1.6822 - val_rmse: 1.6822
# Epoch 505/700
# 1/1 - 0s - loss: 0.4926 - rmse: 0.4925 - val_loss: 1.6839 - val_rmse: 1.6839
# Epoch 506/700
# 1/1 - 0s - loss: 0.4901 - rmse: 0.4900 - val_loss: 1.6851 - val_rmse: 1.6850
# Epoch 507/700
# 1/1 - 0s - loss: 0.4875 - rmse: 0.4874 - val_loss: 1.6864 - val_rmse: 1.6863
# Epoch 508/700
# 1/1 - 0s - loss: 0.4850 - rmse: 0.4849 - val_loss: 1.6878 - val_rmse: 1.6877
# Epoch 509/700
# 1/1 - 0s - loss: 0.4824 - rmse: 0.4823 - val_loss: 1.6891 - val_rmse: 1.6890
# Epoch 510/700
# 1/1 - 0s - loss: 0.4798 - rmse: 0.4797 - val_loss: 1.6908 - val_rmse: 1.6907
# Epoch 511/700
# 1/1 - 0s - loss: 0.4772 - rmse: 0.4772 - val_loss: 1.6921 - val_rmse: 1.6920
# Epoch 512/700
# 1/1 - 0s - loss: 0.4746 - rmse: 0.4745 - val_loss: 1.6932 - val_rmse: 1.6932
# Epoch 513/700
# 1/1 - 0s - loss: 0.4720 - rmse: 0.4719 - val_loss: 1.6953 - val_rmse: 1.6952
# Epoch 514/700
# 1/1 - 0s - loss: 0.4694 - rmse: 0.4694 - val_loss: 1.6966 - val_rmse: 1.6965
# Epoch 515/700
# 1/1 - 0s - loss: 0.4668 - rmse: 0.4667 - val_loss: 1.6980 - val_rmse: 1.6979
# Epoch 516/700
# 1/1 - 0s - loss: 0.4642 - rmse: 0.4641 - val_loss: 1.6998 - val_rmse: 1.6998
# Epoch 517/700
# 1/1 - 0s - loss: 0.4615 - rmse: 0.4615 - val_loss: 1.7013 - val_rmse: 1.7012
# Epoch 518/700
# 1/1 - 0s - loss: 0.4589 - rmse: 0.4588 - val_loss: 1.7028 - val_rmse: 1.7027
# Epoch 519/700
# 1/1 - 0s - loss: 0.4563 - rmse: 0.4562 - val_loss: 1.7046 - val_rmse: 1.7045
# Epoch 520/700
# 1/1 - 0s - loss: 0.4536 - rmse: 0.4536 - val_loss: 1.7060 - val_rmse: 1.7059
# Epoch 521/700
# 1/1 - 0s - loss: 0.4510 - rmse: 0.4509 - val_loss: 1.7076 - val_rmse: 1.7075
# Epoch 522/700
# ...
# Epoch 526/700
# 1/1 - 0s - loss: 0.4377 - rmse: 0.4376 - val_loss: 1.7156 - val_rmse: 1.7156
# Epoch 527/700
# 1/1 - 0s - loss: 0.4350 - rmse: 0.4350 - val_loss: 1.7175 - val_rmse: 1.7174
# Epoch 528/700
# 1/1 - 0s - loss: 0.4324 - rmse: 0.4323 - val_loss: 1.7188 - val_rmse: 1.7187
# Epoch 529/700
# 1/1 - 0s - loss: 0.4297 - rmse: 0.4296 - val_loss: 1.7207 - val_rmse: 1.7206
# Epoch 530/700
# 1/1 - 0s - loss: 0.4271 - rmse: 0.4270 - val_loss: 1.7221 - val_rmse: 1.7221
# Epoch 531/700
# 1/1 - 0s - loss: 0.4244 - rmse: 0.4243 - val_loss: 1.7239 - val_rmse: 1.7238
# Epoch 532/700
# 1/1 - 0s - loss: 0.4217 - rmse: 0.4217 - val_loss: 1.7253 - val_rmse: 1.7252
# Epoch 533/700
# 1/1 - 0s - loss: 0.4191 - rmse: 0.4190 - val_loss: 1.7272 - val_rmse: 1.7271
# Epoch 534/700
# 1/1 - 0s - loss: 0.4164 - rmse: 0.4164 - val_loss: 1.7285 - val_rmse: 1.7285
# Epoch 535/700
# 1/1 - 0s - loss: 0.4138 - rmse: 0.4137 - val_loss: 1.7304 - val_rmse: 1.7303
# Epoch 536/700
# 1/1 - 0s - loss: 0.4111 - rmse: 0.4111 - val_loss: 1.7318 - val_rmse: 1.7317
# Epoch 537/700
# 1/1 - 0s - loss: 0.4085 - rmse: 0.4084 - val_loss: 1.7336 - val_rmse: 1.7335
# Epoch 538/700
# 1/1 - 0s - loss: 0.4058 - rmse: 0.4058 - val_loss: 1.7350 - val_rmse: 1.7349
# Epoch 539/700
# 1/1 - 0s - loss: 0.4032 - rmse: 0.4031 - val_loss: 1.7369 - val_rmse: 1.7368
# Epoch 540/700
# 1/1 - 0s - loss: 0.4005 - rmse: 0.4005 - val_loss: 1.7382 - val_rmse: 1.7381
# Epoch 541/700
# 1/1 - 0s - loss: 0.3979 - rmse: 0.3978 - val_loss: 1.7401 - val_rmse: 1.7400
# Epoch 542/700
# 1/1 - 0s - loss: 0.3952 - rmse: 0.3951 - val_loss: 1.7414 - val_rmse: 1.7414
# Epoch 543/700
# 1/1 - 0s - loss: 0.3925 - rmse: 0.3925 - val_loss: 1.7433 - val_rmse: 1.7432
# Epoch 544/700
# 1/1 - 0s - loss: 0.3899 - rmse: 0.3898 - val_loss: 1.7446 - val_rmse: 1.7446
# Epoch 545/700
# 1/1 - 0s - loss: 0.3872 - rmse: 0.3872 - val_loss: 1.7465 - val_rmse: 1.7464
# Epoch 546/700
# 1/1 - 0s - loss: 0.3846 - rmse: 0.3845 - val_loss: 1.7478 - val_rmse: 1.7477
# Epoch 547/700
# 1/1 - 0s - loss: 0.3820 - rmse: 0.3819 - val_loss: 1.7497 - val_rmse: 1.7496
# Epoch 548/700
# 1/1 - 0s - loss: 0.3793 - rmse: 0.3793 - val_loss: 1.7509 - val_rmse: 1.7508
# Epoch 549/700
# 1/1 - 0s - loss: 0.3767 - rmse: 0.3766 - val_loss: 1.7527 - val_rmse: 1.7527
# Epoch 550/700
# 1/1 - 0s - loss: 0.3741 - rmse: 0.3740 - val_loss: 1.7541 - val_rmse: 1.7540
# Epoch 551/700
# 1/1 - 0s - loss: 0.3714 - rmse: 0.3714 - val_loss: 1.7559 - val_rmse: 1.7558
# Epoch 552/700
# 1/1 - 0s - loss: 0.3688 - rmse: 0.3687 - val_loss: 1.7572 - val_rmse: 1.7571
# Epoch 553/700
# 1/1 - 0s - loss: 0.3662 - rmse: 0.3661 - val_loss: 1.7591 - val_rmse: 1.7590
# Epoch 554/700
# 1/1 - 0s - loss: 0.3636 - rmse: 0.3635 - val_loss: 1.7603 - val_rmse: 1.7603
# Epoch 555/700
# 1/1 - 0s - loss: 0.3609 - rmse: 0.3609 - val_loss: 1.7622 - val_rmse: 1.7621
# Epoch 556/700
# 1/1 - 0s - loss: 0.3583 - rmse: 0.3582 - val_loss: 1.7636 - val_rmse: 1.7635
# Epoch 557/700
# 1/1 - 0s - loss: 0.3557 - rmse: 0.3556 - val_loss: 1.7653 - val_rmse: 1.7653
# Epoch 558/700
# 1/1 - 0s - loss: 0.3531 - rmse: 0.3530 - val_loss: 1.7667 - val_rmse: 1.7666
# Epoch 559/700
# 1/1 - 0s - loss: 0.3504 - rmse: 0.3504 - val_loss: 1.7685 - val_rmse: 1.7685
# Epoch 560/700
# 1/1 - 0s - loss: 0.3478 - rmse: 0.3477 - val_loss: 1.7699 - val_rmse: 1.7698
# Epoch 561/700
# 1/1 - 0s - loss: 0.3452 - rmse: 0.3451 - val_loss: 1.7717 - val_rmse: 1.7717
# Epoch 562/700
# 1/1 - 0s - loss: 0.3426 - rmse: 0.3425 - val_loss: 1.7731 - val_rmse: 1.7730
# Epoch 563/700
# 1/1 - 0s - loss: 0.3399 - rmse: 0.3399 - val_loss: 1.7749 - val_rmse: 1.7749
# Epoch 564/700
# 1/1 - 0s - loss: 0.3374 - rmse: 0.3373 - val_loss: 1.7762 - val_rmse: 1.7761
# Epoch 565/700
# 1/1 - 0s - loss: 0.3347 - rmse: 0.3346 - val_loss: 1.7781 - val_rmse: 1.7780
# Epoch 566/700
# 1/1 - 0s - loss: 0.3321 - rmse: 0.3320 - val_loss: 1.7794 - val_rmse: 1.7793
# Epoch 567/700
# 1/1 - 0s - loss: 0.3295 - rmse: 0.3294 - val_loss: 1.7813 - val_rmse: 1.7813
# Epoch 568/700
# 1/1 - 0s - loss: 0.3269 - rmse: 0.3268 - val_loss: 1.7826 - val_rmse: 1.7825
# Epoch 569/700
# 1/1 - 0s - loss: 0.3243 - rmse: 0.3242 - val_loss: 1.7845 - val_rmse: 1.7844
# Epoch 570/700
# 1/1 - 0s - loss: 0.3216 - rmse: 0.3216 - val_loss: 1.7859 - val_rmse: 1.7858
# Epoch 571/700
# 1/1 - 0s - loss: 0.3190 - rmse: 0.3189 - val_loss: 1.7877 - val_rmse: 1.7876
# Epoch 572/700
# 1/1 - 0s - loss: 0.3164 - rmse: 0.3163 - val_loss: 1.7890 - val_rmse: 1.7889
# Epoch 573/700
# 1/1 - 0s - loss: 0.3138 - rmse: 0.3137 - val_loss: 1.7909 - val_rmse: 1.7909
# Epoch 574/700
# 1/1 - 0s - loss: 0.3112 - rmse: 0.3111 - val_loss: 1.7922 - val_rmse: 1.7922
# Epoch 575/700
# 1/1 - 0s - loss: 0.3086 - rmse: 0.3085 - val_loss: 1.7942 - val_rmse: 1.7941
# Epoch 576/700
# 1/1 - 0s - loss: 0.3059 - rmse: 0.3059 - val_loss: 1.7955 - val_rmse: 1.7954
# Epoch 577/700
# 1/1 - 0s - loss: 0.3033 - rmse: 0.3033 - val_loss: 1.7973 - val_rmse: 1.7973
# Epoch 578/700
# 1/1 - 0s - loss: 0.3007 - rmse: 0.3007 - val_loss: 1.7987 - val_rmse: 1.7986
# Epoch 579/700
# 1/1 - 0s - loss: 0.2981 - rmse: 0.2981 - val_loss: 1.8006 - val_rmse: 1.8005
# Epoch 580/700
# 1/1 - 0s - loss: 0.2955 - rmse: 0.2954 - val_loss: 1.8019 - val_rmse: 1.8018
# Epoch 581/700
# 1/1 - 0s - loss: 0.2929 - rmse: 0.2928 - val_loss: 1.8038 - val_rmse: 1.8038
# Epoch 582/700
# 1/1 - 0s - loss: 0.2903 - rmse: 0.2903 - val_loss: 1.8051 - val_rmse: 1.8050
# Epoch 583/700
# 1/1 - 0s - loss: 0.2877 - rmse: 0.2877 - val_loss: 1.8069 - val_rmse: 1.8068
# Epoch 584/700
# 1/1 - 0s - loss: 0.2851 - rmse: 0.2851 - val_loss: 1.8084 - val_rmse: 1.8083
# Epoch 585/700
# 1/1 - 0s - loss: 0.2826 - rmse: 0.2825 - val_loss: 1.8102 - val_rmse: 1.8102
# Epoch 586/700
# 1/1 - 0s - loss: 0.2800 - rmse: 0.2799 - val_loss: 1.8114 - val_rmse: 1.8114
# Epoch 587/700
# 1/1 - 0s - loss: 0.2774 - rmse: 0.2773 - val_loss: 1.8134 - val_rmse: 1.8133
# Epoch 588/700
# 1/1 - 0s - loss: 0.2748 - rmse: 0.2748 - val_loss: 1.8147 - val_rmse: 1.8146
# Epoch 589/700
# 1/1 - 0s - loss: 0.2723 - rmse: 0.2722 - val_loss: 1.8165 - val_rmse: 1.8164
# Epoch 590/700
# 1/1 - 0s - loss: 0.2697 - rmse: 0.2696 - val_loss: 1.8179 - val_rmse: 1.8178
# Epoch 591/700
# 1/1 - 0s - loss: 0.2671 - rmse: 0.2671 - val_loss: 1.8198 - val_rmse: 1.8197
# Epoch 592/700
# 1/1 - 0s - loss: 0.2646 - rmse: 0.2645 - val_loss: 1.8210 - val_rmse: 1.8209
# Epoch 593/700
# 1/1 - 0s - loss: 0.2620 - rmse: 0.2620 - val_loss: 1.8229 - val_rmse: 1.8229
# Epoch 594/700
# 1/1 - 0s - loss: 0.2595 - rmse: 0.2594 - val_loss: 1.8242 - val_rmse: 1.8241
# Epoch 595/700
# 1/1 - 0s - loss: 0.2569 - rmse: 0.2569 - val_loss: 1.8260 - val_rmse: 1.8259
# Epoch 596/700
# 1/1 - 0s - loss: 0.2544 - rmse: 0.2543 - val_loss: 1.8274 - val_rmse: 1.8274
# Epoch 597/700
# 1/1 - 0s - loss: 0.2519 - rmse: 0.2518 - val_loss: 1.8292 - val_rmse: 1.8291
# Epoch 598/700
# 1/1 - 0s - loss: 0.2493 - rmse: 0.2492 - val_loss: 1.8305 - val_rmse: 1.8305
# Epoch 599/700
# 1/1 - 0s - loss: 0.2468 - rmse: 0.2467 - val_loss: 1.8325 - val_rmse: 1.8324
# Epoch 600/700
# 1/1 - 0s - loss: 0.2442 - rmse: 0.2441 - val_loss: 1.8339 - val_rmse: 1.8338
# Epoch 601/700
# 1/1 - 0s - loss: 0.2416 - rmse: 0.2415 - val_loss: 1.8358 - val_rmse: 1.8357
# Epoch 602/700
# 1/1 - 0s - loss: 0.2390 - rmse: 0.2389 - val_loss: 1.8378 - val_rmse: 1.8377
# Epoch 603/700
# 1/1 - 0s - loss: 0.2363 - rmse: 0.2363 - val_loss: 1.8398 - val_rmse: 1.8397
# Epoch 604/700
# 1/1 - 0s - loss: 0.2337 - rmse: 0.2336 - val_loss: 1.8415 - val_rmse: 1.8415
# Epoch 605/700
# 1/1 - 0s - loss: 0.2311 - rmse: 0.2310 - val_loss: 1.8437 - val_rmse: 1.8437
# Epoch 606/700
# 1/1 - 0s - loss: 0.2285 - rmse: 0.2284 - val_loss: 1.8454 - val_rmse: 1.8453
# Epoch 607/700
# 1/1 - 0s - loss: 0.2259 - rmse: 0.2258 - val_loss: 1.8474 - val_rmse: 1.8473
# Epoch 608/700
# 1/1 - 0s - loss: 0.2233 - rmse: 0.2232 - val_loss: 1.8492 - val_rmse: 1.8491
# Epoch 609/700
# 1/1 - 0s - loss: 0.2207 - rmse: 0.2206 - val_loss: 1.8511 - val_rmse: 1.8510
# Epoch 610/700
# 1/1 - 0s - loss: 0.2181 - rmse: 0.2180 - val_loss: 1.8526 - val_rmse: 1.8526
# Epoch 611/700
# 1/1 - 0s - loss: 0.2156 - rmse: 0.2155 - val_loss: 1.8547 - val_rmse: 1.8546
# Epoch 612/700
# 1/1 - 0s - loss: 0.2130 - rmse: 0.2129 - val_loss: 1.8561 - val_rmse: 1.8560
# Epoch 613/700
# 1/1 - 0s - loss: 0.2104 - rmse: 0.2104 - val_loss: 1.8582 - val_rmse: 1.8581
# Epoch 614/700
# 1/1 - 0s - loss: 0.2079 - rmse: 0.2078 - val_loss: 1.8596 - val_rmse: 1.8595
# Epoch 615/700
# 1/1 - 0s - loss: 0.2054 - rmse: 0.2053 - val_loss: 1.8611 - val_rmse: 1.8610
# Epoch 616/700
# 1/1 - 0s - loss: 0.2029 - rmse: 0.2029 - val_loss: 1.8624 - val_rmse: 1.8624
# Epoch 617/700
# 1/1 - 0s - loss: 0.2005 - rmse: 0.2004 - val_loss: 1.8641 - val_rmse: 1.8640
# Epoch 618/700
# 1/1 - 0s - loss: 0.1981 - rmse: 0.1980 - val_loss: 1.8654 - val_rmse: 1.8654
# Epoch 619/700
# 1/1 - 0s - loss: 0.1957 - rmse: 0.1956 - val_loss: 1.8672 - val_rmse: 1.8671
# Epoch 620/700
# 1/1 - 0s - loss: 0.1933 - rmse: 0.1932 - val_loss: 1.8685 - val_rmse: 1.8685
# Epoch 621/700
# 1/1 - 0s - loss: 0.1909 - rmse: 0.1908 - val_loss: 1.8701 - val_rmse: 1.8701
# Epoch 622/700
# 1/1 - 0s - loss: 0.1885 - rmse: 0.1884 - val_loss: 1.8717 - val_rmse: 1.8716
# Epoch 623/700
# 1/1 - 0s - loss: 0.1861 - rmse: 0.1861 - val_loss: 1.8733 - val_rmse: 1.8732
# Epoch 624/700
# 1/1 - 0s - loss: 0.1838 - rmse: 0.1837 - val_loss: 1.8747 - val_rmse: 1.8747
# Epoch 625/700
# 1/1 - 0s - loss: 0.1814 - rmse: 0.1813 - val_loss: 1.8763 - val_rmse: 1.8763
# Epoch 626/700
# 1/1 - 0s - loss: 0.1791 - rmse: 0.1790 - val_loss: 1.8778 - val_rmse: 1.8777
# Epoch 627/700
# 1/1 - 0s - loss: 0.1767 - rmse: 0.1767 - val_loss: 1.8794 - val_rmse: 1.8794
# Epoch 628/700
# 1/1 - 0s - loss: 0.1744 - rmse: 0.1744 - val_loss: 1.8809 - val_rmse: 1.8809
# Epoch 629/700
# 1/1 - 0s - loss: 0.1721 - rmse: 0.1720 - val_loss: 1.8825 - val_rmse: 1.8824
# Epoch 630/700
# 1/1 - 0s - loss: 0.1698 - rmse: 0.1698 - val_loss: 1.8840 - val_rmse: 1.8839
# Epoch 631/700
# 1/1 - 0s - loss: 0.1675 - rmse: 0.1675 - val_loss: 1.8856 - val_rmse: 1.8856
# Epoch 632/700
# 1/1 - 0s - loss: 0.1653 - rmse: 0.1652 - val_loss: 1.8871 - val_rmse: 1.8870
# Epoch 633/700
# 1/1 - 0s - loss: 0.1630 - rmse: 0.1630 - val_loss: 1.8887 - val_rmse: 1.8886
# Epoch 634/700
# 1/1 - 0s - loss: 0.1608 - rmse: 0.1607 - val_loss: 1.8901 - val_rmse: 1.8900
# Epoch 635/700
# 1/1 - 0s - loss: 0.1586 - rmse: 0.1585 - val_loss: 1.8918 - val_rmse: 1.8917
# Epoch 636/700
# 1/1 - 0s - loss: 0.1564 - rmse: 0.1563 - val_loss: 1.8931 - val_rmse: 1.8930
# Epoch 637/700
# 1/1 - 0s - loss: 0.1542 - rmse: 0.1541 - val_loss: 1.8948 - val_rmse: 1.8947
# Epoch 638/700
# 1/1 - 0s - loss: 0.1520 - rmse: 0.1519 - val_loss: 1.8963 - val_rmse: 1.8962
# Epoch 639/700
# 1/1 - 0s - loss: 0.1498 - rmse: 0.1497 - val_loss: 1.8978 - val_rmse: 1.8977
# Epoch 640/700
# 1/1 - 0s - loss: 0.1477 - rmse: 0.1476 - val_loss: 1.8992 - val_rmse: 1.8992
# Epoch 641/700
# 1/1 - 0s - loss: 0.1455 - rmse: 0.1455 - val_loss: 1.9009 - val_rmse: 1.9008
# Epoch 642/700
# 1/1 - 0s - loss: 0.1434 - rmse: 0.1434 - val_loss: 1.9021 - val_rmse: 1.9021
# Epoch 643/700
# 1/1 - 0s - loss: 0.1413 - rmse: 0.1413 - val_loss: 1.9038 - val_rmse: 1.9037
# Epoch 644/700
# 1/1 - 0s - loss: 0.1393 - rmse: 0.1392 - val_loss: 1.9052 - val_rmse: 1.9051
# Epoch 645/700
# 1/1 - 0s - loss: 0.1372 - rmse: 0.1371 - val_loss: 1.9067 - val_rmse: 1.9067
# Epoch 646/700
# 1/1 - 0s - loss: 0.1351 - rmse: 0.1351 - val_loss: 1.9081 - val_rmse: 1.9080
# Epoch 647/700
# 1/1 - 0s - loss: 0.1331 - rmse: 0.1330 - val_loss: 1.9096 - val_rmse: 1.9096
# Epoch 648/700
# 1/1 - 0s - loss: 0.1311 - rmse: 0.1310 - val_loss: 1.9109 - val_rmse: 1.9109
# Epoch 649/700
# 1/1 - 0s - loss: 0.1291 - rmse: 0.1291 - val_loss: 1.9125 - val_rmse: 1.9124
# Epoch 650/700
# 1/1 - 0s - loss: 0.1272 - rmse: 0.1271 - val_loss: 1.9139 - val_rmse: 1.9138
# Epoch 651/700
# 1/1 - 0s - loss: 0.1252 - rmse: 0.1251 - val_loss: 1.9156 - val_rmse: 1.9155
# Epoch 652/700
# 1/1 - 0s - loss: 0.1231 - rmse: 0.1231 - val_loss: 1.9175 - val_rmse: 1.9174
# Epoch 653/700
# 1/1 - 0s - loss: 0.1211 - rmse: 0.1210 - val_loss: 1.9194 - val_rmse: 1.9193
# Epoch 654/700
# 1/1 - 0s - loss: 0.1192 - rmse: 0.1191 - val_loss: 1.9204 - val_rmse: 1.9203
# Epoch 655/700
# 1/1 - 0s - loss: 0.1172 - rmse: 0.1172 - val_loss: 1.9218 - val_rmse: 1.9217
# Epoch 656/700
# 1/1 - 0s - loss: 0.1154 - rmse: 0.1153 - val_loss: 1.9235 - val_rmse: 1.9234
# Epoch 657/700
# 1/1 - 0s - loss: 0.1136 - rmse: 0.1135 - val_loss: 1.9247 - val_rmse: 1.9247
# Epoch 658/700
# 1/1 - 0s - loss: 0.1117 - rmse: 0.1116 - val_loss: 1.9260 - val_rmse: 1.9259
# Epoch 659/700
# 1/1 - 0s - loss: 0.1099 - rmse: 0.1098 - val_loss: 1.9277 - val_rmse: 1.9276
# Epoch 660/700
# 1/1 - 0s - loss: 0.1081 - rmse: 0.1081 - val_loss: 1.9287 - val_rmse: 1.9286
# Epoch 661/700
# 1/1 - 0s - loss: 0.1064 - rmse: 0.1063 - val_loss: 1.9304 - val_rmse: 1.9303
# Epoch 662/700
# 1/1 - 0s - loss: 0.1046 - rmse: 0.1046 - val_loss: 1.9318 - val_rmse: 1.9317
# Epoch 663/700
# 1/1 - 0s - loss: 0.1029 - rmse: 0.1029 - val_loss: 1.9331 - val_rmse: 1.9330
# Epoch 664/700
# 1/1 - 0s - loss: 0.1012 - rmse: 0.1012 - val_loss: 1.9343 - val_rmse: 1.9342
# Epoch 665/700
# 1/1 - 0s - loss: 0.0996 - rmse: 0.0995 - val_loss: 1.9358 - val_rmse: 1.9357
# Epoch 666/700
# 1/1 - 0s - loss: 0.0979 - rmse: 0.0979 - val_loss: 1.9373 - val_rmse: 1.9372
# Epoch 667/700
# 1/1 - 0s - loss: 0.0963 - rmse: 0.0963 - val_loss: 1.9384 - val_rmse: 1.9384
# Epoch 668/700
# 1/1 - 0s - loss: 0.0947 - rmse: 0.0947 - val_loss: 1.9398 - val_rmse: 1.9397
# Epoch 669/700
# 1/1 - 0s - loss: 0.0931 - rmse: 0.0931 - val_loss: 1.9411 - val_rmse: 1.9410
# Epoch 670/700
# 1/1 - 0s - loss: 0.0916 - rmse: 0.0915 - val_loss: 1.9426 - val_rmse: 1.9426
# Epoch 671/700
# 1/1 - 0s - loss: 0.0900 - rmse: 0.0900 - val_loss: 1.9439 - val_rmse: 1.9438
# Epoch 672/700
# 1/1 - 0s - loss: 0.0885 - rmse: 0.0884 - val_loss: 1.9454 - val_rmse: 1.9453
# Epoch 673/700
# 1/1 - 0s - loss: 0.0870 - rmse: 0.0869 - val_loss: 1.9468 - val_rmse: 1.9467
# Epoch 674/700
# 1/1 - 0s - loss: 0.0855 - rmse: 0.0855 - val_loss: 1.9482 - val_rmse: 1.9481
# Epoch 675/700
# 1/1 - 0s - loss: 0.0841 - rmse: 0.0840 - val_loss: 1.9495 - val_rmse: 1.9495
# Epoch 676/700
# 1/1 - 0s - loss: 0.0827 - rmse: 0.0826 - val_loss: 1.9508 - val_rmse: 1.9507
# Epoch 677/700
# 1/1 - 0s - loss: 0.0813 - rmse: 0.0813 - val_loss: 1.9521 - val_rmse: 1.9520
# Epoch 678/700
# 1/1 - 0s - loss: 0.0800 - rmse: 0.0799 - val_loss: 1.9535 - val_rmse: 1.9534
# Epoch 679/700
# 1/1 - 0s - loss: 0.0786 - rmse: 0.0786 - val_loss: 1.9545 - val_rmse: 1.9545
# Epoch 680/700
# 1/1 - 0s - loss: 0.0773 - rmse: 0.0773 - val_loss: 1.9562 - val_rmse: 1.9561
# Epoch 681/700
# 1/1 - 0s - loss: 0.0760 - rmse: 0.0760 - val_loss: 1.9570 - val_rmse: 1.9570
# Epoch 682/700
# 1/1 - 0s - loss: 0.0748 - rmse: 0.0747 - val_loss: 1.9585 - val_rmse: 1.9584
# Epoch 683/700
# 1/1 - 0s - loss: 0.0735 - rmse: 0.0734 - val_loss: 1.9594 - val_rmse: 1.9594
# Epoch 684/700
# 1/1 - 0s - loss: 0.0723 - rmse: 0.0722 - val_loss: 1.9608 - val_rmse: 1.9607
# Epoch 685/700
# 1/1 - 0s - loss: 0.0711 - rmse: 0.0710 - val_loss: 1.9617 - val_rmse: 1.9617
# Epoch 686/700
# 1/1 - 0s - loss: 0.0700 - rmse: 0.0699 - val_loss: 1.9632 - val_rmse: 1.9631
# Epoch 687/700
# 1/1 - 0s - loss: 0.0688 - rmse: 0.0687 - val_loss: 1.9639 - val_rmse: 1.9638
# Epoch 688/700
# 1/1 - 0s - loss: 0.0677 - rmse: 0.0676 - val_loss: 1.9654 - val_rmse: 1.9653
# Epoch 689/700
# 1/1 - 0s - loss: 0.0666 - rmse: 0.0665 - val_loss: 1.9662 - val_rmse: 1.9661
# Epoch 690/700
# 1/1 - 0s - loss: 0.0655 - rmse: 0.0654 - val_loss: 1.9675 - val_rmse: 1.9674
# Epoch 691/700
# 1/1 - 0s - loss: 0.0645 - rmse: 0.0644 - val_loss: 1.9683 - val_rmse: 1.9683
# Epoch 692/700
# 1/1 - 0s - loss: 0.0634 - rmse: 0.0633 - val_loss: 1.9697 - val_rmse: 1.9697
# Epoch 693/700
# 1/1 - 0s - loss: 0.0624 - rmse: 0.0623 - val_loss: 1.9704 - val_rmse: 1.9703
# Epoch 694/700
# 1/1 - 0s - loss: 0.0614 - rmse: 0.0613 - val_loss: 1.9717 - val_rmse: 1.9716
# Epoch 695/700
# 1/1 - 0s - loss: 0.0604 - rmse: 0.0603 - val_loss: 1.9726 - val_rmse: 1.9725
# Epoch 696/700
# 1/1 - 0s - loss: 0.0594 - rmse: 0.0594 - val_loss: 1.9737 - val_rmse: 1.9736
# Epoch 697/700
# 1/1 - 0s - loss: 0.0585 - rmse: 0.0584 - val_loss: 1.9744 - val_rmse: 1.9744
# Epoch 698/700
# 1/1 - 0s - loss: 0.0576 - rmse: 0.0575 - val_loss: 1.9757 - val_rmse: 1.9757
# Epoch 699/700
# 1/1 - 0s - loss: 0.0566 - rmse: 0.0566 - val_loss: 1.9764 - val_rmse: 1.9764
# Epoch 700/700
# 1/1 - 0s - loss: 0.0557 - rmse: 0.0556 - val_loss: 1.9776 - val_rmse: 1.9775

# %%
pred_ans = model.predict(test_model_input, batch_size=256)
print("test RMSE", round(mean_squared_error(test[target].values, pred_ans, squared=False), 4))
# Out:
# test RMSE 1.9341

# %%
print(pred_ans)
# Out:
# [[2.922055 ]
#  [1.8336217]
#  [3.271982 ]
#  [1.9621656]
#  [2.2523553]
#  [1.9041772]
#  [1.8354471]
#  [2.2885141]
#  [2.0046692]
#  [1.96528  ]
#  [2.8707707]
#  [2.0193365]
#  [2.0747538]
#  [2.0968213]
#  [2.0429196]
#  [2.0178013]
#  [2.0215576]
#  [2.1037204]
#  [2.0603945]
#  [2.0603945]
#  [2.04973  ]
#  [1.8672667]
#  [2.0215576]
#  [1.9922998]
#  [2.1997585]
#  [1.8897955]
#  [2.3505645]
#  [2.340204 ]
#  [2.7153497]
#  [2.2201698]
#  [2.1015005]
#  [2.2190554]
#  [2.2930489]
#  [2.5155478]
#  [2.0693169]
#  [2.1168897]
#  [2.5244236]
#  [2.35313  ]
#  [3.343246 ]
#  [2.3119211]]
